# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
# import
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# 데이터 생성 및 전처리(라벨인코딩만 하고, 원핫인코딩X)

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %% [markdown]
# # 1. 기본적인 DNN(원핫인코딩X)

# %%
# 모델 설정
# model = Sequential()
# model.add(Input(4,))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model = Sequential([
    Input(4,),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.summary() # 250+1530+93 = 1873개 파라미터
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 30)                1530
#
#  dense_2 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습설정
model.compile(loss='sparse_categorical_crossentropy', # 라벨인코딩만 되어 있는 경우
             optimizer='adam',
             metrics=['accuracy'])
# 학습
earlyStropping = EarlyStopping(patience=50) # monitor='val_loss' 기본값
hist = model.fit(train_X, train_y, epochs=1000,
                validation_split=0.2,
                callbacks=[earlyStropping])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 74ms/step - loss: 1.6511 - accuracy: 0.2963 - val_loss: 1.1304 - val_accuracy: 0.4815
# Epoch 2/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3158 - accuracy: 0.2963 - val_loss: 1.0391 - val_accuracy: 0.4815
# Epoch 3/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1430 - accuracy: 0.3056 - val_loss: 1.0293 - val_accuracy: 0.2963
# Epoch 4/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0576 - accuracy: 0.3426 - val_loss: 1.0120 - val_accuracy: 0.2963
# Epoch 5/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9968 - accuracy: 0.3704 - val_loss: 0.9717 - val_accuracy: 0.4074
# Epoch 6/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9346 - accuracy: 0.5185 - val_loss: 0.9167 - val_accuracy: 0.7037
# Epoch 7/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8937 - accuracy: 0.6574 - val_loss: 0.8589 - val_accuracy: 0.7037
# Epoch 8/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8500 - accuracy: 0.6574 - val_loss: 0.7944 - val_accuracy: 0.7037
# Epoch 9/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8114 - accuracy: 0.6574 - val_loss: 0.7412 - val_accuracy: 0.7037
# Epoch 10/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7768 - accuracy: 0.6574 - val_loss: 0.7034 - val_accuracy: 0.7037
# Epoch 11/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7514 - accuracy: 0.6574 - val_loss: 0.6731 - val_accuracy: 0.7037
# Epoch 12/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7282 - accuracy: 0.7037 - val_loss: 0.6472 - val_accuracy: 0.8148
# Epoch 13/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7041 - accuracy: 0.7963 - val_loss: 0.6227 - val_accuracy: 0.8519
# Epoch 14/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6820 - accuracy: 0.8148 - val_loss: 0.6014 - val_accuracy: 0.7778
# Epoch 15/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6609 - accuracy: 0.7222 - val_loss: 0.5843 - val_accuracy: 0.7037
# Epoch 16/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6403 - accuracy: 0.6852 - val_loss: 0.5648 - val_accuracy: 0.7037
# Epoch 17/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6232 - accuracy: 0.6852 - val_loss: 0.5456 - val_accuracy: 0.7037
# Epoch 18/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6056 - accuracy: 0.6852 - val_loss: 0.5226 - val_accuracy: 0.7037
# Epoch 19/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5896 - accuracy: 0.7222 - val_loss: 0.5003 - val_accuracy: 0.7407
# Epoch 20/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5760 - accuracy: 0.7037 - val_loss: 0.4862 - val_accuracy: 0.7037
# Epoch 21/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5603 - accuracy: 0.7685 - val_loss: 0.4672 - val_accuracy: 0.8519
# Epoch 22/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5488 - accuracy: 0.8426 - val_loss: 0.4524 - val_accuracy: 0.9259
# Epoch 23/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5342 - accuracy: 0.9167 - val_loss: 0.4430 - val_accuracy: 0.8889
# Epoch 24/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5204 - accuracy: 0.8611 - val_loss: 0.4345 - val_accuracy: 0.8889
# Epoch 25/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5093 - accuracy: 0.8426 - val_loss: 0.4246 - val_accuracy: 0.8889
# Epoch 26/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4987 - accuracy: 0.8333 - val_loss: 0.4112 - val_accuracy: 0.8889
# Epoch 27/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4869 - accuracy: 0.8611 - val_loss: 0.3977 - val_accuracy: 0.8889
# Epoch 28/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4755 - accuracy: 0.9259 - val_loss: 0.3845 - val_accuracy: 0.9630
# Epoch 29/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4661 - accuracy: 0.9537 - val_loss: 0.3743 - val_accuracy: 0.9630
# Epoch 30/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4567 - accuracy: 0.9352 - val_loss: 0.3697 - val_accuracy: 0.9259
# Epoch 31/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4457 - accuracy: 0.9167 - val_loss: 0.3646 - val_accuracy: 0.9259
# Epoch 32/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4364 - accuracy: 0.9167 - val_loss: 0.3536 - val_accuracy: 0.9259
# Epoch 33/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4251 - accuracy: 0.9259 - val_loss: 0.3392 - val_accuracy: 0.9630
# Epoch 34/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4176 - accuracy: 0.9722 - val_loss: 0.3299 - val_accuracy: 0.9630
# Epoch 35/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4103 - accuracy: 0.9722 - val_loss: 0.3261 - val_accuracy: 0.9630
# Epoch 36/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3986 - accuracy: 0.9630 - val_loss: 0.3169 - val_accuracy: 0.9630
# Epoch 37/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3887 - accuracy: 0.9722 - val_loss: 0.3080 - val_accuracy: 0.9630
# Epoch 38/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3812 - accuracy: 0.9815 - val_loss: 0.3010 - val_accuracy: 0.9630
# Epoch 39/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3717 - accuracy: 0.9815 - val_loss: 0.2975 - val_accuracy: 0.9630
# Epoch 40/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3613 - accuracy: 0.9630 - val_loss: 0.2970 - val_accuracy: 0.9630
# Epoch 41/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3573 - accuracy: 0.9259 - val_loss: 0.2935 - val_accuracy: 0.9259
# Epoch 42/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3471 - accuracy: 0.9352 - val_loss: 0.2782 - val_accuracy: 0.9630
# Epoch 43/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3372 - accuracy: 0.9630 - val_loss: 0.2688 - val_accuracy: 0.9630
# Epoch 44/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3301 - accuracy: 0.9722 - val_loss: 0.2634 - val_accuracy: 0.9630
# Epoch 45/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3216 - accuracy: 0.9815 - val_loss: 0.2582 - val_accuracy: 0.9630
# Epoch 46/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3137 - accuracy: 0.9630 - val_loss: 0.2577 - val_accuracy: 0.9630
# Epoch 47/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3061 - accuracy: 0.9630 - val_loss: 0.2504 - val_accuracy: 0.9630
# Epoch 48/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2984 - accuracy: 0.9722 - val_loss: 0.2401 - val_accuracy: 0.9630
# Epoch 49/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2906 - accuracy: 0.9815 - val_loss: 0.2364 - val_accuracy: 0.9630
# Epoch 50/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2838 - accuracy: 0.9722 - val_loss: 0.2338 - val_accuracy: 0.9630
# Epoch 51/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2780 - accuracy: 0.9722 - val_loss: 0.2245 - val_accuracy: 0.9630
# Epoch 52/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2705 - accuracy: 0.9722 - val_loss: 0.2208 - val_accuracy: 0.9630
# Epoch 53/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2628 - accuracy: 0.9815 - val_loss: 0.2122 - val_accuracy: 0.9630
# Epoch 54/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2567 - accuracy: 0.9815 - val_loss: 0.2057 - val_accuracy: 0.9630
# Epoch 55/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2512 - accuracy: 0.9815 - val_loss: 0.2050 - val_accuracy: 0.9630
# Epoch 56/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2443 - accuracy: 0.9815 - val_loss: 0.2001 - val_accuracy: 0.9630
# Epoch 57/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2377 - accuracy: 0.9815 - val_loss: 0.1942 - val_accuracy: 0.9630
# Epoch 58/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2323 - accuracy: 0.9722 - val_loss: 0.1936 - val_accuracy: 0.9630
# Epoch 59/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2261 - accuracy: 0.9815 - val_loss: 0.1858 - val_accuracy: 0.9630
# Epoch 60/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2219 - accuracy: 0.9815 - val_loss: 0.1814 - val_accuracy: 0.9630
# Epoch 61/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2188 - accuracy: 0.9815 - val_loss: 0.1748 - val_accuracy: 0.9630
# Epoch 62/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2119 - accuracy: 0.9815 - val_loss: 0.1762 - val_accuracy: 0.9630
# Epoch 63/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2064 - accuracy: 0.9815 - val_loss: 0.1764 - val_accuracy: 0.9630
# Epoch 64/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2004 - accuracy: 0.9815 - val_loss: 0.1672 - val_accuracy: 0.9630
# Epoch 65/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1987 - accuracy: 0.9815 - val_loss: 0.1611 - val_accuracy: 0.9259
# Epoch 66/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1951 - accuracy: 0.9907 - val_loss: 0.1591 - val_accuracy: 0.9630
# Epoch 67/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1881 - accuracy: 0.9815 - val_loss: 0.1611 - val_accuracy: 0.9630
# Epoch 68/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1854 - accuracy: 0.9815 - val_loss: 0.1613 - val_accuracy: 0.9630
# Epoch 69/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1795 - accuracy: 0.9815 - val_loss: 0.1510 - val_accuracy: 0.9630
# Epoch 70/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1764 - accuracy: 0.9907 - val_loss: 0.1465 - val_accuracy: 0.9259
# Epoch 71/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1741 - accuracy: 0.9907 - val_loss: 0.1465 - val_accuracy: 0.9630
# Epoch 72/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1690 - accuracy: 0.9815 - val_loss: 0.1489 - val_accuracy: 0.9630
# Epoch 73/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1668 - accuracy: 0.9815 - val_loss: 0.1440 - val_accuracy: 0.9630
# Epoch 74/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1625 - accuracy: 0.9815 - val_loss: 0.1435 - val_accuracy: 0.9630
# Epoch 75/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1597 - accuracy: 0.9815 - val_loss: 0.1406 - val_accuracy: 0.9630
# Epoch 76/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1567 - accuracy: 0.9815 - val_loss: 0.1379 - val_accuracy: 0.9630
# Epoch 77/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1528 - accuracy: 0.9815 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 78/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1501 - accuracy: 0.9815 - val_loss: 0.1306 - val_accuracy: 0.9630
# Epoch 79/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1483 - accuracy: 0.9815 - val_loss: 0.1317 - val_accuracy: 0.9630
# Epoch 80/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1467 - accuracy: 0.9815 - val_loss: 0.1362 - val_accuracy: 0.9630
# Epoch 81/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1454 - accuracy: 0.9815 - val_loss: 0.1290 - val_accuracy: 0.9630
# Epoch 82/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1405 - accuracy: 0.9815 - val_loss: 0.1230 - val_accuracy: 0.9630
# Epoch 83/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1378 - accuracy: 0.9815 - val_loss: 0.1221 - val_accuracy: 0.9630
# Epoch 84/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1354 - accuracy: 0.9815 - val_loss: 0.1237 - val_accuracy: 0.9630
# Epoch 85/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1348 - accuracy: 0.9815 - val_loss: 0.1224 - val_accuracy: 0.9630
# Epoch 86/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1325 - accuracy: 0.9815 - val_loss: 0.1172 - val_accuracy: 0.9630
# Epoch 87/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1301 - accuracy: 0.9815 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 88/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1289 - accuracy: 0.9815 - val_loss: 0.1191 - val_accuracy: 0.9630
# Epoch 89/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1259 - accuracy: 0.9815 - val_loss: 0.1151 - val_accuracy: 0.9630
# Epoch 90/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1280 - accuracy: 0.9815 - val_loss: 0.1104 - val_accuracy: 0.9630
# Epoch 91/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1238 - accuracy: 0.9815 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 92/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1210 - accuracy: 0.9815 - val_loss: 0.1110 - val_accuracy: 0.9630
# Epoch 93/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1176 - accuracy: 0.9815 - val_loss: 0.1071 - val_accuracy: 0.9630
# Epoch 94/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1180 - accuracy: 0.9907 - val_loss: 0.1055 - val_accuracy: 0.9259
# Epoch 95/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1154 - accuracy: 0.9907 - val_loss: 0.1070 - val_accuracy: 0.9630
# Epoch 96/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1154 - accuracy: 0.9815 - val_loss: 0.1125 - val_accuracy: 0.9630
# Epoch 97/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1158 - accuracy: 0.9815 - val_loss: 0.1041 - val_accuracy: 0.9630
# Epoch 98/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1122 - accuracy: 0.9907 - val_loss: 0.1019 - val_accuracy: 0.9259
# Epoch 99/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1106 - accuracy: 0.9907 - val_loss: 0.1011 - val_accuracy: 0.9259
# Epoch 100/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1092 - accuracy: 0.9907 - val_loss: 0.1013 - val_accuracy: 0.9630
# Epoch 101/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1079 - accuracy: 0.9907 - val_loss: 0.1008 - val_accuracy: 0.9630
# Epoch 102/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1064 - accuracy: 0.9815 - val_loss: 0.1021 - val_accuracy: 0.9630
# Epoch 103/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1076 - accuracy: 0.9815 - val_loss: 0.1016 - val_accuracy: 0.9630
# Epoch 104/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1048 - accuracy: 0.9907 - val_loss: 0.0977 - val_accuracy: 0.9259
# Epoch 105/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1068 - accuracy: 0.9815 - val_loss: 0.0968 - val_accuracy: 0.9259
# Epoch 106/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1028 - accuracy: 0.9907 - val_loss: 0.0981 - val_accuracy: 0.9630
# Epoch 107/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1004 - accuracy: 0.9815 - val_loss: 0.0990 - val_accuracy: 0.9630
# Epoch 108/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1002 - accuracy: 0.9815 - val_loss: 0.0993 - val_accuracy: 0.9630
# Epoch 109/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1007 - accuracy: 0.9815 - val_loss: 0.0952 - val_accuracy: 0.9630
# Epoch 110/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0977 - accuracy: 0.9907 - val_loss: 0.0955 - val_accuracy: 0.9630
# Epoch 111/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0970 - accuracy: 0.9815 - val_loss: 0.0945 - val_accuracy: 0.9630
# Epoch 112/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0977 - accuracy: 0.9907 - val_loss: 0.0962 - val_accuracy: 0.9630
# Epoch 113/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0960 - accuracy: 0.9907 - val_loss: 0.0920 - val_accuracy: 0.9259
# Epoch 114/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0965 - accuracy: 0.9907 - val_loss: 0.0916 - val_accuracy: 0.9259
# Epoch 115/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0941 - accuracy: 0.9907 - val_loss: 0.0950 - val_accuracy: 0.9630
# Epoch 116/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0936 - accuracy: 0.9815 - val_loss: 0.0933 - val_accuracy: 0.9630
# Epoch 117/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0925 - accuracy: 0.9815 - val_loss: 0.0931 - val_accuracy: 0.9630
# Epoch 118/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0919 - accuracy: 0.9815 - val_loss: 0.0918 - val_accuracy: 0.9630
# Epoch 119/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0906 - accuracy: 0.9815 - val_loss: 0.0901 - val_accuracy: 0.9630
# Epoch 120/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0892 - accuracy: 0.9907 - val_loss: 0.0889 - val_accuracy: 0.9259
# Epoch 121/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0941 - accuracy: 0.9815 - val_loss: 0.0890 - val_accuracy: 0.9259
# Epoch 122/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0924 - accuracy: 0.9815 - val_loss: 0.0902 - val_accuracy: 0.9630
# Epoch 123/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0876 - accuracy: 0.9815 - val_loss: 0.0900 - val_accuracy: 0.9630
# Epoch 124/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0891 - accuracy: 0.9815 - val_loss: 0.0892 - val_accuracy: 0.9630
# Epoch 125/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0865 - accuracy: 0.9815 - val_loss: 0.0881 - val_accuracy: 0.9259
# Epoch 126/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0922 - accuracy: 0.9815 - val_loss: 0.0869 - val_accuracy: 0.9259
# Epoch 127/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0882 - accuracy: 0.9907 - val_loss: 0.0900 - val_accuracy: 0.9630
# Epoch 128/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0859 - accuracy: 0.9815 - val_loss: 0.0905 - val_accuracy: 0.9630
# Epoch 129/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0868 - accuracy: 0.9907 - val_loss: 0.0870 - val_accuracy: 0.9630
# Epoch 130/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0837 - accuracy: 0.9907 - val_loss: 0.0885 - val_accuracy: 0.9630
# Epoch 131/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0833 - accuracy: 0.9815 - val_loss: 0.0865 - val_accuracy: 0.9630
# Epoch 132/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0826 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9259
# Epoch 133/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0829 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9259
# Epoch 134/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0838 - accuracy: 0.9815 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 135/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0820 - accuracy: 0.9815 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 136/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0804 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 137/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0831 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 138/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0794 - accuracy: 0.9815 - val_loss: 0.0849 - val_accuracy: 0.9630
# Epoch 139/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0856 - accuracy: 0.9815 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 140/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0788 - accuracy: 0.9907 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 141/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0821 - accuracy: 0.9815 - val_loss: 0.0902 - val_accuracy: 0.9630
# Epoch 142/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0816 - accuracy: 0.9815 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 143/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0781 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 144/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0788 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 145/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0799 - accuracy: 0.9815 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 146/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0771 - accuracy: 0.9907 - val_loss: 0.0830 - val_accuracy: 0.9630
# Epoch 147/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0761 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9630
# Epoch 148/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0767 - accuracy: 0.9815 - val_loss: 0.0825 - val_accuracy: 0.9630
# Epoch 149/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0764 - accuracy: 0.9907 - val_loss: 0.0811 - val_accuracy: 0.9259
# Epoch 150/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0758 - accuracy: 0.9907 - val_loss: 0.0818 - val_accuracy: 0.9630
# Epoch 151/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0739 - accuracy: 0.9907 - val_loss: 0.0854 - val_accuracy: 0.9630
# Epoch 152/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0766 - accuracy: 0.9815 - val_loss: 0.0838 - val_accuracy: 0.9630
# Epoch 153/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0768 - accuracy: 0.9815 - val_loss: 0.0809 - val_accuracy: 0.9259
# Epoch 154/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0734 - accuracy: 0.9907 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 155/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0732 - accuracy: 0.9907 - val_loss: 0.0812 - val_accuracy: 0.9630
# Epoch 156/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0728 - accuracy: 0.9907 - val_loss: 0.0801 - val_accuracy: 0.9259
# Epoch 157/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0734 - accuracy: 0.9907 - val_loss: 0.0797 - val_accuracy: 0.9259
# Epoch 158/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0731 - accuracy: 0.9907 - val_loss: 0.0798 - val_accuracy: 0.9259
# Epoch 159/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0716 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 160/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0723 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 161/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0715 - accuracy: 0.9907 - val_loss: 0.0795 - val_accuracy: 0.9259
# Epoch 162/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0708 - accuracy: 0.9907 - val_loss: 0.0795 - val_accuracy: 0.9259
# Epoch 163/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0705 - accuracy: 0.9907 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 164/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0707 - accuracy: 0.9907 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 165/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0714 - accuracy: 0.9907 - val_loss: 0.0821 - val_accuracy: 0.9630
# Epoch 166/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0742 - accuracy: 0.9815 - val_loss: 0.0811 - val_accuracy: 0.9630
# Epoch 167/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0705 - accuracy: 0.9907 - val_loss: 0.0788 - val_accuracy: 0.9259
# Epoch 168/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0710 - accuracy: 0.9815 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 169/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0699 - accuracy: 0.9907 - val_loss: 0.0782 - val_accuracy: 0.9259
# Epoch 170/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0691 - accuracy: 0.9907 - val_loss: 0.0787 - val_accuracy: 0.9259
# Epoch 171/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0690 - accuracy: 0.9907 - val_loss: 0.0807 - val_accuracy: 0.9630
# Epoch 172/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0690 - accuracy: 0.9907 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 173/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0664 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 174/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0807 - accuracy: 0.9722 - val_loss: 0.0830 - val_accuracy: 0.9630
# Epoch 175/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0754 - accuracy: 0.9815 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 176/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0658 - accuracy: 0.9907 - val_loss: 0.0817 - val_accuracy: 0.9630
# Epoch 177/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9815 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 178/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0737 - accuracy: 0.9815 - val_loss: 0.0839 - val_accuracy: 0.9630
# Epoch 179/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0697 - accuracy: 0.9907 - val_loss: 0.0781 - val_accuracy: 0.9259
# Epoch 180/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0672 - accuracy: 0.9907 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 181/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0664 - accuracy: 0.9907 - val_loss: 0.0787 - val_accuracy: 0.9259
# Epoch 182/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0659 - accuracy: 0.9907 - val_loss: 0.0792 - val_accuracy: 0.9630
# Epoch 183/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0662 - accuracy: 0.9907 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 184/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0658 - accuracy: 0.9907 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 185/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0655 - accuracy: 0.9907 - val_loss: 0.0781 - val_accuracy: 0.9259
# Epoch 186/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0658 - accuracy: 0.9907 - val_loss: 0.0776 - val_accuracy: 0.9259
# Epoch 187/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0669 - accuracy: 0.9815 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 188/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0688 - accuracy: 0.9815 - val_loss: 0.0778 - val_accuracy: 0.9259
# Epoch 189/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0657 - accuracy: 0.9907 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 190/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0651 - accuracy: 0.9907 - val_loss: 0.0779 - val_accuracy: 0.9259
# Epoch 191/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0639 - accuracy: 0.9907 - val_loss: 0.0793 - val_accuracy: 0.9630
# Epoch 192/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0660 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9630
# Epoch 193/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0630 - accuracy: 0.9907 - val_loss: 0.0785 - val_accuracy: 0.9259
# Epoch 194/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0668 - accuracy: 0.9815 - val_loss: 0.0804 - val_accuracy: 0.9259
# Epoch 195/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0684 - accuracy: 0.9815 - val_loss: 0.0792 - val_accuracy: 0.9259
# Epoch 196/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0658 - accuracy: 0.9815 - val_loss: 0.0797 - val_accuracy: 0.9630
# Epoch 197/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0691 - accuracy: 0.9815 - val_loss: 0.0843 - val_accuracy: 0.9630
# Epoch 198/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0673 - accuracy: 0.9815 - val_loss: 0.0787 - val_accuracy: 0.9630
# Epoch 199/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0623 - accuracy: 0.9907 - val_loss: 0.0782 - val_accuracy: 0.9259
# Epoch 200/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0648 - accuracy: 0.9815 - val_loss: 0.0787 - val_accuracy: 0.9259
# Epoch 201/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0776 - val_accuracy: 0.9259
# Epoch 202/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0647 - accuracy: 0.9907 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 203/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0610 - accuracy: 0.9907 - val_loss: 0.0779 - val_accuracy: 0.9259
# Epoch 204/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0716 - accuracy: 0.9815 - val_loss: 0.0792 - val_accuracy: 0.9259
# Epoch 205/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 0.0843 - val_accuracy: 0.9630
# Epoch 206/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0666 - accuracy: 0.9815 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 207/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0676 - accuracy: 0.9815 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 208/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0623 - accuracy: 0.9907 - val_loss: 0.0772 - val_accuracy: 0.9259
# Epoch 209/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9907 - val_loss: 0.0772 - val_accuracy: 0.9259
# Epoch 210/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0623 - accuracy: 0.9907 - val_loss: 0.0773 - val_accuracy: 0.9259
# Epoch 211/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0631 - accuracy: 0.9907 - val_loss: 0.0820 - val_accuracy: 0.9630
# Epoch 212/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0659 - accuracy: 0.9815 - val_loss: 0.0813 - val_accuracy: 0.9630
# Epoch 213/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0619 - accuracy: 0.9907 - val_loss: 0.0782 - val_accuracy: 0.9259
# Epoch 214/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 0.0784 - val_accuracy: 0.9259
# Epoch 215/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0615 - accuracy: 0.9815 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 216/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0599 - accuracy: 0.9907 - val_loss: 0.0792 - val_accuracy: 0.9259
# Epoch 217/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0613 - accuracy: 0.9907 - val_loss: 0.0791 - val_accuracy: 0.9259
# Epoch 218/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0610 - accuracy: 0.9907 - val_loss: 0.0779 - val_accuracy: 0.9259
# Epoch 219/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0611 - accuracy: 0.9907 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 220/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0595 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9630
# Epoch 221/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0654 - accuracy: 0.9815 - val_loss: 0.0841 - val_accuracy: 0.9630
# Epoch 222/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0638 - accuracy: 0.9815 - val_loss: 0.0776 - val_accuracy: 0.9259
# Epoch 223/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0601 - accuracy: 0.9907 - val_loss: 0.0782 - val_accuracy: 0.9259
# Epoch 224/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 225/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0607 - accuracy: 0.9815 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 226/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0786 - val_accuracy: 0.9259
# Epoch 227/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0599 - accuracy: 0.9907 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 228/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0635 - accuracy: 0.9815 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 229/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9907 - val_loss: 0.0784 - val_accuracy: 0.9259
# Epoch 230/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0622 - accuracy: 0.9815 - val_loss: 0.0785 - val_accuracy: 0.9259
# Epoch 231/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 232/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0600 - accuracy: 0.9907 - val_loss: 0.0804 - val_accuracy: 0.9630
# Epoch 233/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0797 - val_accuracy: 0.9630
# Epoch 234/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0597 - accuracy: 0.9907 - val_loss: 0.0781 - val_accuracy: 0.9259
# Epoch 235/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 236/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 237/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0578 - accuracy: 0.9907 - val_loss: 0.0786 - val_accuracy: 0.9259
# Epoch 238/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0582 - accuracy: 0.9907 - val_loss: 0.0797 - val_accuracy: 0.9630
# Epoch 239/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0809 - val_accuracy: 0.9630
# Epoch 240/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0613 - accuracy: 0.9815 - val_loss: 0.0832 - val_accuracy: 0.9630
# Epoch 241/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0624 - accuracy: 0.9815 - val_loss: 0.0788 - val_accuracy: 0.9630
# Epoch 242/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0771 - val_accuracy: 0.9259
# Epoch 243/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0769 - val_accuracy: 0.9259
# Epoch 244/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0576 - accuracy: 0.9907 - val_loss: 0.0778 - val_accuracy: 0.9259
# Epoch 245/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0613 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9630
# Epoch 246/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0594 - accuracy: 0.9907 - val_loss: 0.0768 - val_accuracy: 0.9259
# Epoch 247/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0585 - accuracy: 0.9907 - val_loss: 0.0761 - val_accuracy: 0.9259
# Epoch 248/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0565 - accuracy: 0.9907 - val_loss: 0.0766 - val_accuracy: 0.9259
# Epoch 249/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0762 - val_accuracy: 0.9259
# Epoch 250/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0568 - accuracy: 0.9907 - val_loss: 0.0769 - val_accuracy: 0.9259
# Epoch 251/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0766 - val_accuracy: 0.9259
# Epoch 252/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0566 - accuracy: 0.9907 - val_loss: 0.0763 - val_accuracy: 0.9259
# Epoch 253/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0758 - val_accuracy: 0.9259
# Epoch 254/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0755 - val_accuracy: 0.9259
# Epoch 255/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0564 - accuracy: 0.9907 - val_loss: 0.0755 - val_accuracy: 0.9259
# Epoch 256/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0574 - accuracy: 0.9815 - val_loss: 0.0758 - val_accuracy: 0.9259
# Epoch 257/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0788 - val_accuracy: 0.9630
# Epoch 258/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0573 - accuracy: 0.9907 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 259/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0561 - accuracy: 0.9907 - val_loss: 0.0767 - val_accuracy: 0.9259
# Epoch 260/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0573 - accuracy: 0.9907 - val_loss: 0.0769 - val_accuracy: 0.9259
# Epoch 261/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0564 - accuracy: 0.9907 - val_loss: 0.0791 - val_accuracy: 0.9630
# Epoch 262/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0569 - accuracy: 0.9907 - val_loss: 0.0784 - val_accuracy: 0.9259
# Epoch 263/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0579 - accuracy: 0.9907 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 264/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0548 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9630
# Epoch 265/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0601 - accuracy: 0.9907 - val_loss: 0.0809 - val_accuracy: 0.9630
# Epoch 266/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0563 - accuracy: 0.9907 - val_loss: 0.0781 - val_accuracy: 0.9259
# Epoch 267/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0585 - accuracy: 0.9815 - val_loss: 0.0783 - val_accuracy: 0.9259
# Epoch 268/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0563 - accuracy: 0.9907 - val_loss: 0.0780 - val_accuracy: 0.9259
# Epoch 269/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0546 - accuracy: 0.9907 - val_loss: 0.0777 - val_accuracy: 0.9259
# Epoch 270/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0560 - accuracy: 0.9815 - val_loss: 0.0792 - val_accuracy: 0.9259
# Epoch 271/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0596 - accuracy: 0.9815 - val_loss: 0.0835 - val_accuracy: 0.9630
# Epoch 272/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0576 - accuracy: 0.9815 - val_loss: 0.0793 - val_accuracy: 0.9259
# Epoch 273/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0531 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 274/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9630
# Epoch 275/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0573 - accuracy: 0.9907 - val_loss: 0.0809 - val_accuracy: 0.9259
# Epoch 276/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0592 - accuracy: 0.9907 - val_loss: 0.0797 - val_accuracy: 0.9259
# Epoch 277/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0589 - accuracy: 0.9815 - val_loss: 0.0801 - val_accuracy: 0.9259
# Epoch 278/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0546 - accuracy: 0.9907 - val_loss: 0.0787 - val_accuracy: 0.9259
# Epoch 279/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0541 - accuracy: 0.9907 - val_loss: 0.0787 - val_accuracy: 0.9259
# Epoch 280/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0554 - accuracy: 0.9815 - val_loss: 0.0786 - val_accuracy: 0.9259
# Epoch 281/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0535 - accuracy: 0.9907 - val_loss: 0.0798 - val_accuracy: 0.9259
# Epoch 282/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0544 - accuracy: 0.9907 - val_loss: 0.0801 - val_accuracy: 0.9259
# Epoch 283/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0545 - accuracy: 0.9907 - val_loss: 0.0799 - val_accuracy: 0.9259
# Epoch 284/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0539 - accuracy: 0.9907 - val_loss: 0.0788 - val_accuracy: 0.9259
# Epoch 285/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 286/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0560 - accuracy: 0.9815 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 287/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0548 - accuracy: 0.9815 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 288/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 0.0799 - val_accuracy: 0.9259
# Epoch 289/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0550 - accuracy: 0.9815 - val_loss: 0.0810 - val_accuracy: 0.9259
# Epoch 290/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.0802 - val_accuracy: 0.9259
# Epoch 291/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0540 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9630
# Epoch 292/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 293/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0812 - val_accuracy: 0.9259
# Epoch 294/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0526 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 295/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 0.0801 - val_accuracy: 0.9259
# Epoch 296/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0530 - accuracy: 0.9815 - val_loss: 0.0804 - val_accuracy: 0.9259
# Epoch 297/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 0.9907 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 298/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0833 - val_accuracy: 0.9630
# Epoch 299/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9259
# Epoch 300/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0565 - accuracy: 0.9815 - val_loss: 0.0813 - val_accuracy: 0.9259
# Epoch 301/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0530 - accuracy: 0.9815 - val_loss: 0.0802 - val_accuracy: 0.9259
# Epoch 302/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0546 - accuracy: 0.9907 - val_loss: 0.0812 - val_accuracy: 0.9259
# Epoch 303/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0529 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9259
# Epoch 304/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0536 - accuracy: 0.9815 - val_loss: 0.0810 - val_accuracy: 0.9259
# Epoch 305/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0539 - accuracy: 0.9815 - val_loss: 0.0802 - val_accuracy: 0.9259

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩을 하지 않고 라벨인코딩까지만 해야 작동. numpy배열

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 머신러닝 3장 교안 43page
mlp_model = MLPClassifier(hidden_layer_sizes=(50,30),
                     activation='relu', 
                     solver='adam',
                     alpha=0.0001, # 과적합 방지 강도
                     batch_size=40,
                     max_iter=1000, # epoch
                     early_stopping=True, # 조기 종료 활성화(val_loss)
                     n_iter_no_change=50, # patience
                     warm_start=False, # True일 경우 이전학습에 이어서 학습 
                     validation_fraction=0.1) # 검증셋 비율

# %%
mlp_model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True, hidden_layer_sizes=(50, 30),
#               max_iter=1000, n_iter_no_change=50)

# %%
# 모델 평가 : accuracy(test_X,test_y), recall, precision(test_y, yhat)
from sklearn.metrics import recall_score, precision_score
accuracy = mlp_model.score(test_X, test_y)
yhat = mlp_model.predict(test_X)
recall = recall_score(test_y, yhat, average='weighted')
precision = precision_score(test_y, yhat, average='weighted')
print('정확도 :', accuracy)
print('재현율 :', recall)
print('정밀도 :', precision)
print('교차표\n', pd.crosstab(test_y, yhat, 
                           rownames=['실제'],
                           colnames=['예측']))
# Out:
# 정확도 : 0.9333333333333333
# 재현율 : 0.9333333333333333
# 정밀도 : 0.9444444444444445
# 교차표
#  예측  0  1  2
# 실제
# 0   5  0  0
# 1   0  4  1
# 2   0  0  5

# %% [markdown]
# # 3. 클래스 이용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', optimizer='adam'):
        # 모델 구성
#         model = Sequential()
#         model.add(Input(input_dim,))
#         model.add(Dense(50, activation=activation))
#         model.add(Dense(30, activation=activation))
#         model.add(Dense(3, activation='softmax'))
        model = Sequential([
            Input(input_dim,) ,
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(3, activation='softmax')
        ])
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        return model

# %%
# %%time
# 모델
model = DNNClassifier.build(input_dim=4, activation='relu')
model.summary()
# 모델 학습
hist = model.fit(train_X, train_y,
                epochs=500,
                validation_split=0.2,
                verbose=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                250
#
#  dense_4 (Dense)             (None, 30)                1530
#
#  dense_5 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 22.6 s
# Wall time: 18.5 s

# %%
loss, accuracy = model.evaluate(test_X, test_y)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0249 - accuracy: 1.0000
# (0.024933544918894768, 1.0)

# %% [markdown]
# # 4. 함수형 API이용하기
# - 병렬처리 : 속도 높이려고
# - 레지듀얼블록(Residual block) : 모델의 성능을 높이려고(자연어처리,이미지처리)

# %%
# import
import numpy as np
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras import Model # 모델 생성(입력층과 출력층을 이용)
from tensorflow.keras.layers import Dense, Input, add # add :레지듀얼블록 
from tensorflow.keras.layers import concatenate # 병렬처리시

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %%
# 기존의 model 스타일 4 -> 50 -> 30 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=30, activation='relu')(dense1)
dense3 = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=dense3)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=20,
         validation_split=0.2)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 4)]               0
#
#  dense_6 (Dense)             (None, 50)                250
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 1s 71ms/step - loss: 1.2040 - accuracy: 0.3889 - val_loss: 1.0907 - val_accuracy: 0.5556
# Epoch 2/20
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0582 - accuracy: 0.4630 - val_loss: 1.0698 - val_accuracy: 0.2222
# Epoch 3/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9902 - accuracy: 0.3611 - val_loss: 1.0307 - val_accuracy: 0.2222
# Epoch 4/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9437 - accuracy: 0.3611 - val_loss: 0.9804 - val_accuracy: 0.2963
# Epoch 5/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9035 - accuracy: 0.5185 - val_loss: 0.9224 - val_accuracy: 0.7037
# Epoch 6/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8634 - accuracy: 0.6574 - val_loss: 0.8667 - val_accuracy: 0.7037
# Epoch 7/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8238 - accuracy: 0.7037 - val_loss: 0.8100 - val_accuracy: 0.7037
# Epoch 8/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7866 - accuracy: 0.7407 - val_loss: 0.7571 - val_accuracy: 0.7037
# Epoch 9/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7492 - accuracy: 0.7315 - val_loss: 0.7119 - val_accuracy: 0.7037
# Epoch 10/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7176 - accuracy: 0.7037 - val_loss: 0.6755 - val_accuracy: 0.7037
# Epoch 11/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6872 - accuracy: 0.6759 - val_loss: 0.6464 - val_accuracy: 0.7037
# Epoch 12/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6599 - accuracy: 0.6944 - val_loss: 0.6147 - val_accuracy: 0.7037
# Epoch 13/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6358 - accuracy: 0.7130 - val_loss: 0.5975 - val_accuracy: 0.7037
# Epoch 14/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6126 - accuracy: 0.7130 - val_loss: 0.5672 - val_accuracy: 0.7037
# Epoch 15/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5905 - accuracy: 0.7500 - val_loss: 0.5351 - val_accuracy: 0.7778
# Epoch 16/20
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5678 - accuracy: 0.8241 - val_loss: 0.5083 - val_accuracy: 0.7778
# Epoch 17/20
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5496 - accuracy: 0.8611 - val_loss: 0.4823 - val_accuracy: 0.8519
# Epoch 18/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5304 - accuracy: 0.8889 - val_loss: 0.4651 - val_accuracy: 0.8148
# Epoch 19/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5124 - accuracy: 0.8889 - val_loss: 0.4494 - val_accuracy: 0.8148
# Epoch 20/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4968 - accuracy: 0.8519 - val_loss: 0.4376 - val_accuracy: 0.7778

# %%
# 병렬처리
# 4 -> 160(50,80,30로 병렬처리) -> 32 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(160, activation='relu')(input_)의 병렬처리
dense4 = Dense(32, activation='relu')(x)
output = Dense(3, activation='softmax')(dense4)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 4)]          0           []
#
#  dense_9 (Dense)                (None, 50)           250         ['input_4[0][0]']
#
#  dense_10 (Dense)               (None, 80)           400         ['input_4[0][0]']
#
#  dense_11 (Dense)               (None, 30)           150         ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_9[0][0]',
#                                                                   'dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 32)           5152        ['concatenate[0][0]']
#
#  dense_13 (Dense)               (None, 3)            99          ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 6,051
# Trainable params: 6,051
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
# 레지듀얼블록(Residual Block):딥러닝에서 딥한 네트워크가 학습이 잘 되지 않을 때
# 4 -> 50 -> 50 ->(레지듀얼)-> 3
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(3, activation='softmax')(dense3)
model = Model(inputs=input_, outputs=output)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=500,
         validation_split=0.2, verbose=0)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 4)]          0           []
#
#  dense_14 (Dense)               (None, 50)           250         ['input_5[0][0]']
#
#  dense_15 (Dense)               (None, 50)           2550        ['dense_14[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_14[0][0]',
#                                                                   'dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________
# CPU times: total: 24 s
# Wall time: 18.4 s

# %%
model.evaluate(test_X, test_y)
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0294 - accuracy: 1.0000
# [0.029445325955748558, 1.0]
