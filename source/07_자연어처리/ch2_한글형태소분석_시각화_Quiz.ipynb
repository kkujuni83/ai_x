# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # ※ ①naver open API를 활용하여 네이버지식인 "전주여행"과 "경주여행"을 각각 500건씩 검색(re ? )후 백업 -> ②품사태깅 백업 -> ③명사만 추출 -> ④빈도분석(DataFrame) 후 백업-> ⑤빈도 시각화(워드클라우드, Text) ->⑥ Word2Vec

# %% [markdown]
# # 1. 네이버 open API를 활용하여 검색 추출
# - 검색어, no, title, link, description, title + ' ' + description(total_text)

# %%
# pip install python-dotenv (환경변수를 쓰기 위한 라이브러리)
# pip install python-decouple (주피터 환경에서는 안 될 수도 있음)
import os
os.getcwd() # 현재 작업디렉토리
# Out:
# 'C:\\ai_x\\source\\07_자연어처리'

# %%
# %ls .env
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 3664-591E
#
#  C:\ai_x\source\07_자연어처리 디렉터리
#
# 2025-06-19  오후 03:44                56 .env
#                1개 파일                  56 바이트
#                0개 디렉터리  89,542,889,472 바이트 남음

# %%
from dotenv import load_dotenv
load_dotenv()

# print(os.getenv('Client_ID'))
# print(os.getenv('Client_Secret'))
# Out:
# True

# %%
from decouple import config
# print(config('Client_ID'))
# print(config('Client_Secret'))

# %%
# 네이버 개발자 센터 document에 있는 내용 그냥 그대로 가져와 봄
import os
import sys
import urllib.request
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
encText = urllib.parse.quote("경주 여행")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8')[:500])
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 19 Jun 2025 16:14:03 +0900",
# 	"total":931234,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>경주 여행<\/b>코스 루지월드 해방감을 느꼈어요",
# 			"link":"https:\/\/blog.naver.com\/sangil00\/223903211939",
# 			"description":"오랜만에 활기차고 건강하게 하루를 보낼 수 있었고요. 날씨 좋은 계절에 경주를 방문하신다면 루지월드를 꼭 <b>경주 여행<\/b>코스에 넣어보시길 바라요. 정말 후회 없는 경험이 될 거예요. #<b>경주여행<\/b>코스 #루지월드",
# 			"bloggername":"길을 찾는 즐거움_거칠부",
# 			"bloggerlink":"blog.naver.com\/sangil00",
# 			"postdate":"20250618"
# 		},
# 		{
# 			"title":"당일치기 <

# %%
# 패키지 import
import requests
import time
import os
import json # response 텍스트를 json 딕셔너리로
from html import unescape # description에 있는 &lt;(특수문자)을 <으로 변경, &gt;-> >
import pandas as pd
import re

# %%
query = "경주 여행"
start = 1
url = f"https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start}"
headers = {"X-Naver-Client-Id":client_id,
           "X-Naver-Client-Secret":client_secret}
response = requests.get(url, headers=headers)
items = json.loads(response.text)['items']
print(len(items))
print(items[51],items[58])
# Out:
# 100
# {'title': '<b>경주 여행</b> 코스 어디가★', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=90111&docId=277365452&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8', 'description': '가족들이랑 <b>경주여행</b>을 가려고 하는데 !! <b>경주 여행</b> 코스를 어떻게 해야할지 모르겟네요!! <b>경주 여행</b> 코스 어디가 좋을까요? 사실 중학교때 가보고 안가봤어요 <b>경주 여행</b>코스 가장 핫플레이스만 가보고 싶어요!! 혹시 <b>경주 여행</b>코스 다들... '} {'title': '<b>경주 여행</b>!! 황리단길 맛집추천', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8', 'description': '이번주에 <b>경주여행</b> 가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ <b>경주 여행</b>을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달... '}

# %%
item = items[58]
title = item['title']
link = item['link']
description = item['description']
print(title, link, description, sep='\n')
# Out:
# <b>경주 여행</b>!! 황리단길 맛집추천
# https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8
# 이번주에 <b>경주여행</b> 가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ <b>경주 여행</b>을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달...

# %%
# 위의 title의 <b>태그 없애기, description의 <b>태그 없애고 html의 특수문자 없애기
item = items[58]
title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
link = item['link']
description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
print(title, link, description, sep='\n')
# Out:
#  경주 여행 !! 황리단길 맛집추천
# https://kin.naver.com/qna/detail.naver?d1id=9&dirId=901&docId=451834956&qb=6rK97KO8IOyXrO2WiQ==&enc=utf8
# 이번주에  경주여행  가는데 황리단길 근처로 맛집 많이 추천해주세요 ~ 뚜벅이라 거리멀면 힘들어요 ㅠㅠ  경주 여행 을 위한 황리단길 맛집 추천과 황리단 맛집과 경주 맛집은 매일 많은 분들이 줄을 오랫동안 서서 기다려 먹는 곳과 배달...

# %%
import re
description = "#추억여행 ####ktx 타고@짱@ ㅎㅎㅎ ㅠㅠ ㅋㅋ"

# 정규표현식: 알파벳, 숫자, 한글만 남기고 나머지는 제거
description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
description = re.sub('\s+', ' ', description)
print(description)
# Out:
#  추억여행 ktx 타고 짱

# %%
# 네이버 API 계정 정보
from dotenv import load_dotenv
import os
load_dotenv()
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
queries = ['전주 여행', '경주 여행']
max_start = 5

# %%
# 방법1
def get_search_element_save(query, start):
    headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
    url = f'https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start}'
    response = requests.get(url, headers=headers)
    items = json.loads(response.text)['items']
    for i, item in enumerate(items):
        title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
        link = item['link']
        description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
#         print('수정전 :', description)
        description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        description = re.sub('\s+', ' ', description)
#         print('수정후 :', description)
        # print(query, (start*100+i+1), title, link, description, title+' ' +description)
        with open(file_name, 'a', encoding='utf-8') as file:
            file.write('{}\t{}\t{}\t{}\t{}\t{}\n'.format(query, 
                                                         (start-1)*100+i+1,
                                                         title,
                                                         link,
                                                         description, 
                                                         title + ' ' +description))

# %%
# 데이터를 저장할 파일 생성 (naver_kin.txt)하고 title 저장(header저장)
file_name = 'data/naver_kin.csv'
with open(file_name, 'w', encoding='utf-8') as file:
    file.write('{}\t{}\t{}\t{}\t{}\t{}\n'.format('query', 
                            'no','title','link', 'description', 'total_text'))

# %%
for query in queries:
    for start in range(1, max_start+1):
        print(start, query, '읽는 중')
        get_search_element_save(query, start)
        time.sleep(0.5)
# Out:
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 5 전주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중
# 5 경주 여행 읽는 중

# %%
# 방법2 (수업시간 내용과 동일)
def get_search_element_return(query, start):
    headers = {'X-Naver-Client-Id':client_id,
           'X-Naver-Client-Secret':client_secret}
    url = f'https://openapi.naver.com/v1/search/kin.json?query={query}&display=100&start={start}'
    response = requests.get(url, headers=headers)
    items = json.loads(response.text)['items']
    result = []
    for i, item in enumerate(items):
        title = item['title'].replace('<b>', ' ').replace('</b>', ' ')
        link = item['link']
        description = item['description'].replace('<b>', ' ').replace('</b>', ' ')
#         print('수정전 :', description)
        description = unescape(description) # html 특수문자 처리(&lt; -> <로 대체)
        description = re.sub(r'[^a-zA-Z0-9가-힣]', ' ', description)
        description = re.sub('\s+', ' ', description)
#         print('수정후 :', description)
        # print(query, (start*100+i+1), title, link, description, title+' ' +description)
        result.append({'query':query,
                      'no':(start-1)*100+i+1,
                      'title':title,
                      'link':link,
                      'description':description,
                      'total_text':title+ ' ' + description})
    return result

# %%
result_total = []
for query in queries:
    for start in range(1, max_start+1):
        print(start, query, '읽는 중')
        result_total.extend(get_search_element_return(query, start))
        time.sleep(0.5)
df = pd.DataFrame(result_total)
df.to_csv('data/naver_kin.csv', index=False, sep='\t')
# Out:
# 1 전주 여행 읽는 중
# 2 전주 여행 읽는 중
# 3 전주 여행 읽는 중
# 4 전주 여행 읽는 중
# 5 전주 여행 읽는 중
# 1 경주 여행 읽는 중
# 2 경주 여행 읽는 중
# 3 경주 여행 읽는 중
# 4 경주 여행 읽는 중
# 5 경주 여행 읽는 중

# %% [markdown]
# # 2. 품사태깅 백업

# %%
import pandas as pd
df = pd.read_csv('data/naver_kin.csv', sep='\t')
df.head(2)
# Out:
#    query  no              title  \
# 0  전주 여행   1   전주  가볼만한곳 추천 받아요
# 1  전주 여행   2      전주여행 갈려고하는데요!
#
#                                                 link  \
# 0  https://kin.naver.com/qna/detail.naver?d1id=9&...
# 1  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                          description  \
# 0   추억의 7080 다양한체험 7080감성 추억여행 테마박물관 유익한시간 2 전북 전...
# 1   전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔은 좋은가격에 정했고 음 2...
#
#                                           total_text
# 0   전주  가볼만한곳 추천 받아요  추억의 7080 다양한체험 7080감성 추억여행 ...
# 1   전주여행 갈려고하는데요!  전주여행 을 갈려고하는데요 아는사람과 갈려고하는데 호텔...

# %%
df_list = df[['query','no','total_text']].values.tolist()
df_list[::500]
# Out:
# [['전주 여행',
#   1,
#   ' 전주  가볼만한곳 추천 받아요  추억의 7080 다양한체험 7080감성 추억여행 테마박물관 유익한시간 2 전북 전북투어패스 통합이용권 전북핫플 여러여행지 다양한체험 카페이용추가 전주여행 필수 편안하고 즐거운 날이 되시길 바라겠습니다 감사합니다 '],
#  ['경주 여행',
#   1,
#   '추석에  경주 여행  추석에 경주 여행 가는거 어떻게 생각하시나요 서울에서 버스를 타고 갈 경우 버스가 버스전용 차선에서 운행하나요 질문하신 추석 경주여행 관련 답변 드리도록 하겠습니다 첨성대 석굴암 불국사 등 유적지는 연중무휴로 ']]

# %%
from konlpy.tag import Komoran, Kkma, Hannanum, Okt
from mecab import MeCab
analyzer = MeCab()
stopwords = ['전주','경주','여행']
select_pos = ['NNG', 'NNP']

# %%
postagged_lst = []
for i, row in enumerate(df_list):
    query = row[0]
    no = row[1]
    text = row[2]
    text_pos = analyzer.pos(text)
    # analyzer가 MeCab이 아닐 경우 시간이 좀 걸려서 250개마다 로그 출력
#     if i%250==0:
#         print("{}의 {}번째 품사태깅 결과 {}개 저장중".format(query, 
#                                                 no, 
#                                                 len(text_pos), end='\n\n'))
    for token, pos in text_pos:
        # if token not in stopwords and pos in select_pos: 라고 하면 명사만 추출
        if token not in stopwords and len(token)>1: # 모든 품사를 우선 다 넣고 나중에 빼려면
            postagged_lst.append({'query':query,
                                 'no':no,
                                 'token':token,
                                 'pos':pos})
df_postagged = pd.DataFrame(postagged_lst)
df_postagged
# Out:
#        query   no token  pos
# 0      전주 여행    1    추천  NNG
# 1      전주 여행    1    아요   EF
# 2      전주 여행    1    추억  NNG
# 3      전주 여행    1  7080   SN
# 4      전주 여행    1    다양  NNG
# ...      ...  ...   ...  ...
# 24218  경주 여행  500    참고  NNG
# 24219  경주 여행  500    쭈니  NNP
# 24220  경주 여행  500    아빠  NNG
# 24221  경주 여행  500   블로그  NNG
# 24222  경주 여행  500    방문  NNG
#
# [24223 rows x 4 columns]

# %%
df_postagged.to_csv('data/naver_kin_pos.csv', index=False, sep='\t')

# %% [markdown]
# # 3. 명사만 추출

# %%
df_postagged = pd.read_csv('data/naver_kin_pos.csv', sep='\t')

# %%
df_nouns = df_postagged.loc[df_postagged['pos'].isin(['NNP', 'NNG']),
                            ['query', 'token','pos']]
df_nouns.head()
# Out:
#    query token  pos
# 0  전주 여행    추천  NNG
# 2  전주 여행    추억  NNG
# 4  전주 여행    다양  NNG
# 5  전주 여행    체험  NNG
# 7  전주 여행    감성  NNG

# %%
df_nouns.to_csv('data/naver_kin_pos_nouns.csv', index=False, sep='\t')

# %% [markdown]
# # 4.빈도분석(DataFrame) 후 백업

# %%
df_nouns = pd.read_csv('data/naver_kin_pos_nouns.csv', sep='\t')
df_nouns.shape
# Out:
# (14106, 3)

# %%
df_nouns.iloc[::5000]
# Out:
#        query token  pos
# 0      전주 여행    추천  NNG
# 5000   전주 여행    코스  NNG
# 10000  경주 여행    학년  NNG

# %%
df_nouns.groupby(['query','token'], as_index=False)['pos'].count()
# Out:
#      query token  pos
# 0    경주 여행    가격   10
# 1    경주 여행    가능   24
# 2    경주 여행   가본적    5
# 3    경주 여행    가성    5
# 4    경주 여행    가시    5
# ..     ...   ...  ...
# 878  전주 여행    환급    5
# 879  전주 여행    회관    5
# 880  전주 여행    휴가    5
# 881  전주 여행    휴무    5
# 882  전주 여행    흐노    5
#
# [883 rows x 3 columns]

# %%
df_token_grp = df_nouns.groupby('query')['token'].value_counts()
df_token_grp
# Out:
# query  token
# 경주 여행  코스       446
#        추천       406
#        계획       154
#        숙소       139
#        맛집       130
#                ...
# 전주 여행  카페이        1
#        통합         1
#        패스         1
#        편안         1
#        필수         1
# Name: count, Length: 883, dtype: int64

# %%
df_token_grp = df_token_grp.reset_index(name='token_count')
df_token_grp.head()
# Out:
#    query token  token_count
# 0  경주 여행    코스          446
# 1  경주 여행    추천          406
# 2  경주 여행    계획          154
# 3  경주 여행    숙소          139
# 4  경주 여행    맛집          130

# %%
# 전주 여행과 경우 여행 여행 빈도 추출
import numpy as np
a = pd.DataFrame([['단어1', 90],
                 ['단어2',80]], columns=['단어','경주빈도'])
b = pd.DataFrame([['단어1', 99],
                 ['단어3',81]], columns=['단어','전주빈도'])
display(a)
display(b)
ab = pd.merge(a, b, 
         how='outer', # inner(공통), left, right, outer
         on='단어')   # 두 프레임을 어떤 열 기준으로 합칠지 지정
#pd.concat([a, b], axis=1)
ab.fillna(0, inplace=True)
ab['경주빈도'] = ab['경주빈도'].astype(np.int16)
ab['전주빈도'] = ab['전주빈도'].astype('int')
ab.info()
# Out:
#     단어  경주빈도
# 0  단어1    90
# 1  단어2    80
#     단어  전주빈도
# 0  단어1    99
# 1  단어3    81
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   단어      3 non-null      object
#  1   경주빈도    3 non-null      int16
#  2   전주빈도    3 non-null      int32
# dtypes: int16(1), int32(1), object(1)
# memory usage: 170.0+ bytes

# %%
df_gj = df_token_grp.loc[df_token_grp['query']=='경주 여행', ['token','token_count']]
df_jj = df_token_grp.loc[df_token_grp['query']=='전주 여행', ['token','token_count']]
df_gj.shape, df_jj.shape
# Out:
# ((460, 2), (423, 2))

# %%
df_gj.head()
# Out:
#   token  token_count
# 0    코스          446
# 1    추천          406
# 2    계획          154
# 3    숙소          139
# 4    맛집          130

# %%
df_jj.head()
# Out:
#     token  token_count
# 460    코스          481
# 461    여수          349
# 462    주달          304
# 463    추천          301
# 464    맛집          287

# %%
df_mrg = pd.merge(df_gj, df_jj, how='outer', on='token')
print(df_mrg.shape)
df_mrg
# Out:
# (712, 3)
#     token  token_count_x  token_count_y
# 0      가격           10.0           22.0
# 1      가능           24.0           30.0
# 2    가보세요            NaN            5.0
# 3     가본적            5.0            NaN
# 4      가성            5.0            NaN
# ..    ...            ...            ...
# 707    휴무            NaN            5.0
# 708   휴무일            4.0            NaN
# 709    휴식            5.0            NaN
# 710    흐노            NaN            5.0
# 711    흥미            5.0            NaN
#
# [712 rows x 3 columns]

# %%
df_mrg.columns = ['token','경주빈도','전주빈도']
df_mrg.fillna(0, inplace=True)
df_mrg['경주빈도'] = df_mrg['경주빈도'].astype('int')
df_mrg['전주빈도'] = df_mrg['전주빈도'].astype(np.int64) # 'int64'
df_mrg
# Out:
#     token  경주빈도  전주빈도
# 0      가격    10    22
# 1      가능    24    30
# 2    가보세요     0     5
# 3     가본적     5     0
# 4      가성     5     0
# ..    ...   ...   ...
# 707    휴무     0     5
# 708   휴무일     4     0
# 709    휴식     5     0
# 710    흐노     0     5
# 711    흥미     5     0
#
# [712 rows x 3 columns]

# %%
df_mrg['빈도합'] = df_mrg['경주빈도'] + df_mrg['전주빈도']
df_mrg['전주비율'] = df_mrg['전주빈도'] / df_mrg['빈도합']
df_mrg['경주비율'] = df_mrg['경주빈도'] / df_mrg['빈도합']
df_mrg.head(10)
# Out:
#   token  경주빈도  전주빈도  빈도합      전주비율      경주비율
# 0    가격    10    22   32  0.687500  0.312500
# 1    가능    24    30   54  0.555556  0.444444
# 2  가보세요     0     5    5  1.000000  0.000000
# 3   가본적     5     0    5  0.000000  1.000000
# 4    가성     5     0    5  0.000000  1.000000
# 5    가시     5     0    5  0.000000  1.000000
# 6    가실     5     5   10  0.500000  0.500000
# 7    가여     5     0    5  0.000000  1.000000
# 8    가요    18     7   25  0.280000  0.720000
# 9   가운데     0     5    5  1.000000  0.000000

# %%
df_mrg_srt = df_mrg.sort_values(by=['빈도합'], ascending=False)
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합      전주비율      경주비율
# 619    코스   446   481  927  0.518878  0.481122
# 601    추천   406   301  707  0.425743  0.574257
# 195    맛집   130   287  417  0.688249  0.311751
# 381    여수     0   349  349  1.000000  0.000000
# 530    주달     0   304  304  1.000000  0.000000
# ..    ...   ...   ...  ...       ...       ...
# 393  연중무휴     1     0    1  0.000000  1.000000
# 93     권역     1     0    1  0.000000  1.000000
# 430    운행     1     0    1  0.000000  1.000000
# 612   카페이     0     1    1  1.000000  0.000000
# 645    패스     0     1    1  1.000000  0.000000
#
# [712 rows x 6 columns]

# %%
df_mrg_srt['전주비율'] = df_mrg_srt['전주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg_srt['경주비율'] = df_mrg_srt['경주비율'].apply(lambda x : "{:.2%}".format(x))
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합     전주비율     경주비율
# 619    코스   446   481  927   51.89%   48.11%
# 601    추천   406   301  707   42.57%   57.43%
# 195    맛집   130   287  417   68.82%   31.18%
# 381    여수     0   349  349  100.00%    0.00%
# 530    주달     0   304  304  100.00%    0.00%
# ..    ...   ...   ...  ...      ...      ...
# 393  연중무휴     1     0    1    0.00%  100.00%
# 93     권역     1     0    1    0.00%  100.00%
# 430    운행     1     0    1    0.00%  100.00%
# 612   카페이     0     1    1  100.00%    0.00%
# 645    패스     0     1    1  100.00%    0.00%
#
# [712 rows x 6 columns]

# %%
df_mrg_srt.reset_index(drop=True, inplace=True)
df_mrg_srt
# Out:
#     token  경주빈도  전주빈도  빈도합     전주비율     경주비율
# 0      코스   446   481  927   51.89%   48.11%
# 1      추천   406   301  707   42.57%   57.43%
# 2      맛집   130   287  417   68.82%   31.18%
# 3      여수     0   349  349  100.00%    0.00%
# 4      주달     0   304  304  100.00%    0.00%
# ..    ...   ...   ...  ...      ...      ...
# 707  연중무휴     1     0    1    0.00%  100.00%
# 708    권역     1     0    1    0.00%  100.00%
# 709    운행     1     0    1    0.00%  100.00%
# 710   카페이     0     1    1  100.00%    0.00%
# 711    패스     0     1    1  100.00%    0.00%
#
# [712 rows x 6 columns]

# %%
df_mrg_srt.to_csv('data/naver_kin_pos_nouns_count.txt', sep='\t')

# %% [markdown]
# # 5. 빈도 시각화(워드클라우드, Text)

# %%
df_nouns = pd.read_csv('data/naver_kin_pos_nouns.csv', sep='\t')
print(df_nouns.shape)
df_nouns.iloc[::3000]
# Out:
# (14106, 3)
#        query token  pos
# 0      전주 여행    추천  NNG
# 3000   전주 여행    시간  NNG
# 6000   전주 여행    실내  NNG
# 9000   경주 여행    남자  NNG
# 12000  경주 여행  테마파크  NNG

# %%
df_nouns['pos'].unique()
# Out:
# array(['NNG', 'NNP'], dtype=object)

# %%
df_gj_noun = df_nouns.loc[df_nouns['query']=='경주 여행','token'].to_list()
df_jj_noun = df_nouns.loc[df_nouns['query']=='전주 여행','token'].to_list()
print(df_gj_noun[:5])
print(df_jj_noun[:5])
gj = ' '.join(df_gj_noun)
jj = ' '.join(df_jj_noun)
print(gj[:10])
print(jj[:10])
# Out:
# ['추석', '추석', '생각', '서울', '버스']
# ['추천', '추억', '다양', '체험', '감성']
# 추석 추석 생각 서
# 추천 추억 다양 체

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
color_map = "Blues"
font_path = 'data/NanumPenScript-Regular.ttf'

# %%
import numpy as np
from PIL import Image
mask = np.array(Image.open('data/heart.jpg'))
불용어 = set(['여행'])
wordcloud = WordCloud(
    background_color='white',
    colormap=color_map,
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex황리단같은거는 같이
    max_words=200,
    max_font_size=200,
    scale=2, # 이미지 크기의 비율(다운로드시 달라짐)
    random_state=777,
    font_path = font_path,
    stopwords=불용어,
    mask = mask,
    contour_color='blue',
    contour_width=1
).generate(gj)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_kin_경주.jpg')

# %%
import numpy as np
from PIL import Image
mask = np.array(Image.open('data/korea-house-black-fill.png'))
불용어 = set(['여행'])
wordcloud = WordCloud(
    background_color='white',
    colormap=color_map,
    collocations=True, # 특정단어가 자주 같이 나오면 같이 뿌려 ex황리단같은거는 같이
    max_words=200,
    max_font_size=100,
    scale=2, # 이미지 크기의 비율(다운로드시 달라짐)
    random_state=777,
    font_path = font_path,
    stopwords=불용어,
    mask = mask,
    contour_color='blue',
    contour_width=1
).generate(jj)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# 생성된 wordcloud 저장
wordcloud.to_file('data/naver_kin_전주.jpg')

# %% [markdown]
# ## 단어의 빈도수 시각화(nltk.Text)

# %%
import pandas as pd
df_nouns = pd.read_csv('data/naver_kin_pos_nouns.csv', sep='\t')
df_gj_noun = df_nouns.loc[df_nouns['query']=='경주 여행','token'].to_list()
df_jj_noun = df_nouns.loc[df_nouns['query']=='전주 여행','token'].to_list()
print(df_gj_noun[:5])
print(df_jj_noun[:5])
# Out:
# ['추석', '추석', '생각', '서울', '버스']
# ['추천', '추억', '다양', '체험', '감성']

# %%
import nltk
import matplotlib.pyplot as plt
data_text = nltk.Text(df_gj_noun)
plt.figure(figsize=(15,4))
plt.rc('font', family='Malgun Gothic')
data_text.plot(15)
plt.show()

# %%
word, counts = zip(*data_text.vocab().most_common(15))
plt.figure(figsize=(15,3))
plt.plot(word, counts)
plt.xticks(rotation=45)
plt.xlabel('word')
plt.ylabel('count')
plt.title('경주 최빈단어')
plt.show()

# %%
import nltk
import matplotlib.pyplot as plt
data_text = nltk.Text(df_jj_noun)
plt.figure(figsize=(15,4))
plt.rc('font', family='Malgun Gothic')
data_text.plot(15)
plt.show()

# %%
word, counts = zip(*data_text.vocab().most_common(15))
plt.figure(figsize=(15,3))
plt.plot(word, counts)
plt.xticks(rotation=45)
plt.xlabel('word')
plt.ylabel('count')
plt.title('전주 최빈단어')
plt.show()

# %% [markdown]
# # 6. Word2Vec

# %%
import pandas as pd
df = pd.read_csv('data/naver_kin.csv', sep='\t')
df.sample()
# Out:
#      query   no           title  \
# 667  경주 여행  168   경주 여행  렌터카 문의
#
#                                                   link  \
# 667  https://kin.naver.com/qna/detail.naver?d1id=9&...
#
#                                            description  \
# 667   경주여행 을 가려고 합니다 우선 숙소는 터미널 주요 관광지를 도보 5 10분 경주...
#
#                                             total_text
# 667   경주 여행  렌터카 문의  경주여행 을 가려고 합니다 우선 숙소는 터미널 주요 관...

# %%
total_text_list = df['total_text'].to_list()
total_text_list[-2:]
# Out:
# ['2박  경주여행  11월 중순에 남편과 경주여행 을 계획하고 있는데요 처음 가보는곳이라 첫날은 황남관한옥호텔 에서 1박하고 이튿날은 청공한옥스테이에서 1박 총 2박3일 계획인데요 여행스케쥴을 어떻게 ',
#  ' 경주 여행 지 추천  2 부산을 벗어난 경주 여행 지 알려주세요 3 당일치기로 경주 여행 코스 밑에 자세하게 권역별로 여행코스를 소개했습니다 경주여행 이 처음이라면 대릉원 첨성대 참고로 쭈니아빠 블로그를 방문하시면 경주여행 ']

# %%
select_pos = ['NNP', 'NNG'] # Komoran, Kkma, MeCab의 일반명사, 고유명사
# select_pos = ['Noun'] # Okt의 일반명사, 고유명사
# select_pos = ['NC', 'NQ']# Hannanum의 보통명사, 고유명사
불용어 = {'여행'}

# %%
# %%time
from konlpy.tag import Komoran, Kkma, Hannanum, Okt
from mecab import MeCab
analyzer = MeCab()
total_noun_list = []
for total_text in total_text_list:
    noun_list = [token for token, tag in analyzer.pos(total_text) 
                     if tag in select_pos and 
                             len(token)>1 and
                             token not in 불용어] # 명사, 2글자이상, 불용어제외
    total_noun_list.append(noun_list)
# Out:
# CPU times: total: 797 ms
# Wall time: 794 ms

# %%
print(total_noun_list[-2:])
# Out:
# [['경주', '중순', '남편', '경주', '계획', '첫날', '황남', '호텔', '이튿날', '청공', '옥스', '테이', '계획'], ['경주', '추천', '부산', '경주', '당일', '경주', '코스', '권역', '코스', '소개', '경주', '처음', '대릉원', '첨성대', '참고', '쭈니', '아빠', '블로그', '방문', '경주']]

# %%
from gensim.models import Word2Vec
model = Word2Vec(total_noun_list, window=10, min_count=2, workers=-1, 
                 sg=1) # 소량데이터에 더 잘 맞음

# %%
model.wv.most_similar('전주')
# Out:
# [('연령', 0.3641005754470825),
#  ('자연', 0.2186741828918457),
#  ('콘도', 0.2163221687078476),
#  ('초보', 0.2159893810749054),
#  ('완산구', 0.21469098329544067),
#  ('비빔', 0.2134207934141159),
#  ('공용', 0.20914915204048157),
#  ('관광공사', 0.20906011760234833),
#  ('위치', 0.2070489227771759),
#  ('활용', 0.20607849955558777)]

# %%
model.wv.most_similar('경주')
# Out:
# [('전통문화', 0.3595535457134247),
#  ('월지', 0.2897421717643738),
#  ('진행', 0.275379478931427),
#  ('필수', 0.2731468081474304),
#  ('텍스', 0.2580290138721466),
#  ('서울', 0.22950327396392822),
#  ('반려', 0.2202327698469162),
#  ('제주', 0.21883946657180786),
#  ('일정', 0.21617145836353302),
#  ('기지', 0.2135322242975235)]

# %%
print('2번이상 나와서 학습된 단어들 : ',list(model.wv.index_to_key))
print(len(model.wv))
# Out:
# 2번이상 나와서 학습된 단어들 :  ['경주', '전주', '코스', '추천', '맛집', '여수', '주달', '계획', '숙소', '일정', '한옥마을', '질문', '부탁', '티비', '국내', '답변', '제주', '전문', '언서', '제주도', '봉이', '한옥', '친구', '마을', '가족', '안녕', '참고', '당일치기', '황리', '관련', '이번', '택시', '정도', '예정', '준비', '공원', '근처', '버스', '시간', '엄마', '이용', '아이', '터미널', '가능', '장소', '아래', '추억', '날씨', '관광지', '덕진', '역사', '문화', '방문', '도움', '남자', '동선', '운전', '혼자', '식당', '관광', '시작', '이동', '갈만', '사람', '카페', '당일', '투어', '시장', '여자', '주말', '렌트', '대중교통', '월지', '동물원', '펜션', '첨성대', '불국사', '아빠', '부모', '거리', '도착', '어머니', '동궁', '체험', '감사', '비용', '가격', '박물관', '전라도', '포항', '기차', '아들', '정보', '수목원', '호텔', '소개', '서울', '생각', '플레이스', '도시', '루트', '강아지', '명소', '처음', '학년', '남부', '첨부', '볼거리', '도보', '지도', '국립', '고등학생', '하루', '가요', '위주', '야경', '특별', '추석', '얼마', '석굴암', '확인', '대부분', '시내', '경비', '평일', '실패', '예약', '다음', '채택', '포함', '교통편', '게스트', '렌트카', '월드', '경험', '산책', '한국', '시절', '한복', '향교', '초등', '동안', '반려', '하우스', '요소', '필요', '동반', '완산구', '선택', '마음', '정리', '대릉원', '블로그', '부산', '저녁', '음식', '토요일', '여유', '천마총', '가이드', '신라', '보문', '주신', '블로거', '맞춤', '교통비', '남산', '기본', '분위기', '경북', '경기전', '친정', '자동차', '바닷가', '검색', '주요', '조언', '고등학교', '진행', '빌라', '전통', '가을', '벽화', '빵집', '의견', '인근', '구경', '할머니', '실내', '덕진구', '최소한', '방법', '말씀', '자차', '교통', '예상', '리스트', '점심', '오후', '교동', '오전', '경주역', '바다', '관람', '고민', '내공', '남편', '중순', '문자', '시외버스', '편안', '필수', '금요일', '예보', '쭈니', '복귀', '아침', '수단', '입장료', '엑스포', '지난주', '난장', '사이트', '현대', '대표', '황남빵', '비빔', '가실', '호수', '최고봉', '순서', '생략', '랜드', '초코파이', '방학', '대여', '문제', '전시회', '소리', '사투리', '제시', '크리스마스', '전동성당', '무리', '부족', '생활', '중간', '시대', '자만', '계절', '위치', '안내', '출발', '커플', '날짜', '오푸스', '시기', '경주로', '궁원', '절리', '기간', '주상', '양남', '황성', '사진', '다면', '느낌', '대접', '미술관', '지역', '초보', '현지인', '최적', '쿠지', '이상', '주제', '연령', '패딩', '문화재', '저번', '숙박', '캐리', '어사이즈', '캐리어', '예산', '인원', '이벤트', '고려', '고속버스', '정복', '어머님', '그때', '대상', '관심', '영화제', '요번', '애인', '본인', '보문관광단지', '사월', '단지', '책자', '요금', '완주', '황동', '중앙', '어르신', '초등학생', '한국도로공사', '조절', '여성', '상황', '운영', '정교', '학생', '자가용', '음식점', '목대', '중요', '감성', '자연', '경관', '수원', '추가', '여학생', '황남', '에서', '첫날', '여행지', '유적지', '테마', '기상', '어버이날', '허락', '휴가', '기관', '주천', '흐노', '전망', '금액', '교육', '천차만별', '관광공사', '스로', '세일', '조정', '웨이팅', '전주국', '에도', '데이트', '케이블카', '당장', '주목적', '대둔산', '건물', '경로', '조선', '알짜배기', '요일', '식비', '그램', '더클래식', '일반', '항목', '공간', '스토리', '해설', '방지', '예약금', '달인', '수학', '결제', '현장', '상당', '음료', '기프', '환급', '현재', '마감', '인당', '유명', '일식', '중식', '양식', '침대', '전통문화', '연인', '시설', '트레', '공방', '독일', '페스타', '다랭이', '스타', '변호사', '김선용', '상담', '법률', '지식', '소속', '사회', '변호', '지방', '팀조', '장단점', '광주', '결정', '하늘', '동물', '술값', '내부', '정감', '교통수단', '다윈', '보통', '가운데', '내외', '반양', '체증', '보리암', '선착순', '슈퍼', '코로나', '초반', '작품', '감상', '수면', '중학교', '언니', '활동', '월드컵', '평지', '조금', '우양', '최초', '궁터', '왕자', '해결책', '건강', '카메라', '오랫동안', '배달', '경기도', '내년', '겨울', '비추', '경치', '군요', '코트', '경량', '행복', '용시', '아버지', '매일', '포토', '파크', '워터', '구성원', '나드리', '의미', '재미', '공부', '여행객', '유산', '움직임', '이틀', '최대한', '구체', '경험담', '예전', '가본적', '지리', '입장', '제외', '테마파크', '대공원', '원릉', '동굴', '봄바람', '객실', '개별', '바베큐', '부부', '먹거리', '잔치국수', '법주', '밀면', '폴라로이드', '구매', '조심', '여동생', '벚꽃', '개화', '카테고리', '선배', '학교', '작년', '여름', '가시', '열차', '정서', '출발지', '형편', '시내버스', '자전거', '안내소', '렌터카', '활용', '새벽', '대명', '콘도', '기림사', '분황사', '부처', '무열왕릉', '황룡', '사지', '오릉', '자녀', '기온', '시즌', '어려움', '주의', '제안', '바탕', '랜드마크', '가여', '마지막', '어른', '독채', '휴식', '수학여행', '추도', '신상', '신축', '지인', '최근', '천군동', '입실', '그동안', '이맘때', '중학', '전남', '식사', '황지', '지역민', '관광객', '취향', '요즘', '경경', '한화', '리조트', '조사', '결과', '카카오', '실행', '자신', '고궁', '편리', '소요', '태교', '주식', '전일', '주만', '피큐어', '평점', '전주식', '한정식', '수구', '전라', '회관', '전주비빔밥', '성미', '요약', '토종', '명품', '사용', '리의', '기지', '생일', '이동은', '욕조', '텍스', '애견', '플랫', '하트', '불편', '문의', '현황', '주문', '실시간', '운송', '답장', '왕복', '기차표', '월요일', '휴무', '걱정', '오픈', '군산', '새만금', '기회', '주이', '수정', '부분', '본점', '대옥', '구용', '도로공사', '갤러리', '주박', '물관', '서신동', '대학', '공연', '연극', '억양', '거북', '의외', '전라북도', '전주시', '통상', '려인', '세염', '메뉴', '조화', '역하', '고택', '참조', '도보이', '바 ...
# 702

# %%
# 유사한 단어 출력
print("입력된 단어와 유사한 단어 10개를 출력합니다.")
key = input()
if key in model.wv:
    print("{}와 유사한 단어:".format(key))
    print(model.wv.most_similar(key, topn=10))
else:
    print("{} 단어가 훈련 데이터에 없음".format(key))
# Out:
# 입력된 단어와 유사한 단어 10개를 출력합니다.
# 한식
# 한식 단어가 훈련 데이터에 없음
