# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch4. RNN(Recurrent Neural Network 순환신경망)</span>

# %% [markdown]
# # 1. 문맥을 이용하여 모델만들기

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
text1 = "장마철이 오고 있다"

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text, text1])
encoded = t.texts_to_sequences([text, text1])
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 2, 6, 1, 7, 8, 1, 9, 10, 1, 11], [12, 13, 2]]
# {'말이': 1, '있다': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11, '장마철이': 12, '오고': 13}

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다','말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5], [1]]
# [8, 1, 11]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는','경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i:시작index
        for j in range(i+2, len(encoded)+1): # j:끝나는 index바로 뒤
            sequences.append(encoded[i:j])
# print(sequences)
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]
# 6

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                # padding='post',
                                padding='pre')
padded_sequences.shape, type(padded_sequences)
#padded_sequences
# Out:
# ((28, 6), numpy.ndarray)

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
# X를 엠베딩 작업할 때 필요한 입력 bit 수 (단어수+1) 
input_dim = len(t.word_index)+1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding # Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim,  # 12개로 원핫인코딩
                   output_dim=10, # 임베딩 출력의 갯수
                   input_length=X.shape[1])) # 입력(X)의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
# 3. 모델 학습 과정 설정
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 10)             120
#
#  simple_rnn (SimpleRNN)      (None, 32)                1376
#
#  dense (Dense)               (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 2s - loss: 2.4833 - accuracy: 0.0357 - 2s/epoch - 2s/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4733 - accuracy: 0.0714 - 5ms/epoch - 5ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4633 - accuracy: 0.1071 - 6ms/epoch - 6ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4533 - accuracy: 0.2143 - 6ms/epoch - 6ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4431 - accuracy: 0.2143 - 6ms/epoch - 6ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4328 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4223 - accuracy: 0.3214 - 8ms/epoch - 8ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.4115 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.4004 - accuracy: 0.3571 - 7ms/epoch - 7ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.3890 - accuracy: 0.3929 - 8ms/epoch - 8ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3771 - accuracy: 0.4286 - 8ms/epoch - 8ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3647 - accuracy: 0.4286 - 9ms/epoch - 9ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3519 - accuracy: 0.4643 - 7ms/epoch - 7ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3385 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.3245 - accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.3099 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.2947 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.2787 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.2620 - accuracy: 0.5357 - 8ms/epoch - 8ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.2446 - accuracy: 0.5357 - 9ms/epoch - 9ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.2265 - accuracy: 0.5714 - 9ms/epoch - 9ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.2076 - accuracy: 0.5714 - 8ms/epoch - 8ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.1881 - accuracy: 0.5714 - 14ms/epoch - 14ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.1679 - accuracy: 0.5714 - 12ms/epoch - 12ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.1470 - accuracy: 0.5714 - 9ms/epoch - 9ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.1257 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.1039 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.0819 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 2.0597 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 2.0375 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 2.0155 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 1.9938 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 1.9727 - accuracy: 0.4286 - 6ms/epoch - 6ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 1.9524 - accuracy: 0.3929 - 7ms/epoch - 7ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9329 - accuracy: 0.3929 - 8ms/epoch - 8ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9145 - accuracy: 0.3571 - 9ms/epoch - 9ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.8972 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.8811 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.8662 - accuracy: 0.3571 - 8ms/epoch - 8ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.8523 - accuracy: 0.3571 - 9ms/epoch - 9ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.8393 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8272 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8156 - accuracy: 0.3571 - 7ms/epoch - 7ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8044 - accuracy: 0.3571 - 10ms/epoch - 10ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.7934 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.7825 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.7716 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.7606 - accuracy: 0.3929 - 11ms/epoch - 11ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.7495 - accuracy: 0.3929 - 10ms/epoch - 10ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.7382 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.7267 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7150 - accuracy: 0.3929 - 7ms/epoch - 7ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7031 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.6911 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.6788 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.6664 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.6538 - accuracy: 0.4643 - 8ms/epoch - 8ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.6410 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.6280 - accuracy: 0.4643 - 4ms/epoch - 4ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.6149 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.6018 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.5885 - accuracy: 0.4643 - 5ms/epoch - 5ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.5751 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.5617 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.5482 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.5347 - accuracy: 0.5000 - 7ms/epoch - 7ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.5211 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.5076 - accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.4940 - accuracy: 0.5000 - 7ms/epoch - 7ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.4804 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.4669 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.4533 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.4398 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.4263 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.4128 - accuracy: 0.5357 - 6ms/epoch - 6ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.3993 - accuracy: 0.5357 - 6ms/epoch - 6ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.3859 - accuracy: 0.5357 - 7ms/epoch - 7ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.3726 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.3592 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.3460 - accuracy: 0.5714 - 9ms/epoch - 9ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.3327 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.3196 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3066 - accuracy: 0.6071 - 7ms/epoch - 7ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.2936 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.2807 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.2679 - accuracy: 0.6071 - 6ms/epoch - 6ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.2552 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.2426 - accuracy: 0.6071 - 5ms/epoch - 5ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.2302 - accuracy: 0.6429 - 6ms/epoch - 6ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2178 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2055 - accuracy: 0.6429 - 5ms/epoch - 5ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.1934 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.1813 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.1695 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.1577 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.1461 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.1346 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1233 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1121 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1010 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.0901 - accuracy: 0.6786 - 8ms/epoch - 8ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.0793 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.0687 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.0582 - accuracy: 0.7143 - 8ms/epoch - 8ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.0478 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0376 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0275 - accuracy: 0.7143 - 7ms/epoch - 7ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0176 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0078 - accuracy: 0.7143 - 7ms/epoch - 7ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.9981 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.9886 - accuracy: 0.7143 - 16ms/epoch - 16ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.9792 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.9700 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.9609 - accuracy: 0.7143 - 7ms/epoch - 7ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9519 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9431 - accuracy: 0.7143 - 6ms/epoch - 6ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9344 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.9258 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.9174 - accuracy: 0.7143 - 6ms/epoch - 6ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9090 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9008 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.8928 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.8848 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.8770 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.8693 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.8617 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.8542 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.8468 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.8396 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8324 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8254 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8185 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8116 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8049 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.7982 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.7917 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.7852 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.7789 - accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.7726 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.7664 - accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.7603 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7543 - accuracy: 0.7500 - 5ms/epoch - 5ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7484 - accuracy: 0.7857 - 14ms/epoch - 14ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7426 - accuracy: 0.7857 - 8ms/epoch - 8ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7368 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7311 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7256 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7200 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7146 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.7092 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.7039 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.6987 - accuracy: 0.7857 - 6ms/epoch - 6ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.6935 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.6884 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.6834 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6784 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6735 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6687 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6639 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6592 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6545 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6499 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6454 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6409 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6364 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6320 - accuracy: 0.8214 - 5ms/epoch - 5ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.6277 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.6234 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.6192 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.6150 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.6108 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.6067 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.6027 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5986 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5947 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5907 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5869 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5830 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5792 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5754 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5717 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5680 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5644 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5607 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5572 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5536 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5501 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5466 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.5432 - accuracy: 0.8571 - 9ms/epoch - 9ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.5398 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.5364 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.5330 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.5297 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.5264 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.5232 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.5199 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.5167 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.5136 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.5104 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.5073 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.5042 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.5012 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4982 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4952 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4922 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4892 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4863 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4834 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4806 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4777 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4749 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4721 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4693 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4666 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4639 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4612 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4585 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4559 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4532 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4506 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4481 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4455 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.4430 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.4405 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.4380 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.4355 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.4331 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.4307 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.4283 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.4259 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.4235 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.4212 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.4189 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.4166 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.4144 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.4121 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.4099 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.4077 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.4055 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.4034 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.4012 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3991 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3970 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3949 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3929 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3908 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3888 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3868 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3849 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3829 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3810 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3791 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3772 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3753 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3734 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3716 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3698 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3680 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3662 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3645 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3627 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3610 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3593 - accuracy: 0.8929 - 17ms/epoch - 17ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3576 - accuracy: 0.8929 - 8ms/epoch - 8ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3559 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3543 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3527 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3510 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3495 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3479 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3463 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3448 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3432 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3417 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3402 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3388 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3373 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3359 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3344 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3330 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3316 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3302 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3289 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.3275 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.3262 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.3249 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.3236 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.3223 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.3210 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.3198 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.3185 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.3173 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.3161 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.3149 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.3137 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.3125 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.3113 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.3102 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.3090 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.3079 - accuracy: 0.8929 - 4ms/epoch - 4ms/step

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %%
# 모델 사용하기 (경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
print('입력데이터 :', input_data)
result = model.predict(input_data, verbose=0).argmax()
word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :가는 말이
# 입력데이터 : [[0 0 0 8 1]]
# 예측된 단어 : 고와야

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 올 단어 3개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    # print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print("{}번째 생성 문맥 {} ({}{})".format(i,
#                                            current_word,
#                                            encoded,
#                                            result) )
    return current_word
sentence_generation('경마장에', 3)
# Out:
# '경마장에 있는 말이 뛰고'

# %%
sentence_generation('가는', 5)
# Out:
# '가는 말이 고와야 오는 말이 곱다'
