# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch2. LLM활용의 기본 개념(Ollama)</span>

# %% [markdown]
# # 1. LLM을 활용하여 답변 생성하기
# ## 1) Ollama 이용한 로컬 LLM 이용
# 성능은 GPT, Claude 같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용

# %% [markdown]
# ### ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull deepseek-r1:1.5b (window키+R => powershell)

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke("What is the capital of Korea?")
result # 추론모델<think>~<think>
# Out:
# AIMessage(content='<think>\n\n</think>\n\nThe capital of Korea, South Korea, is依次 listed为Seoul and Busan.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-06-26T02:34:02.7688769Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4252446100, 'load_duration': 2473943200, 'prompt_eval_count': 10, 'prompt_eval_duration': 333822100, 'eval_count': 23, 'eval_duration': 1441675900, 'model_name': 'deepseek-r1:1.5b'}, id='run--5a201d6a-1dac-4f89-a7c1-5780a30fc4b2-0', usage_metadata={'input_tokens': 10, 'output_tokens': 23, 'total_tokens': 33})

# %% [markdown]
# ### ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull llama3.2:1b (window키+R => powershell)
# - llama : 공식적으로 한글지원 안 됨 (llama3.1 405b한글지원 가능-> llama3.3 70b)
# - exaone : 공식적으로 한글지원

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of Korea?")
result
# Out:
# AIMessage(content="The capital of South Korea is Seoul. However, it's worth noting that the Democratic People's Republic of Korea (North Korea) has its own capital city as well, which is Pyongyang. But if you're referring to South Korea, Seoul is the primary administrative and cultural center.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:34:14.2377449Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6998003200, 'load_duration': 2788349800, 'prompt_eval_count': 32, 'prompt_eval_duration': 639869800, 'eval_count': 57, 'eval_duration': 3568654400, 'model_name': 'llama3.2:1b'}, id='run--6b30b4b2-7e98-4b41-87e0-756a1983cf22-0', usage_metadata={'input_tokens': 32, 'output_tokens': 57, 'total_tokens': 89})

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("너는 다른 AI에 비해 어떤 점이 가장 강점이자 특징이 머야?")
print(result.content)
# Out:
# ฉัน은 많은 지식 및 정보를 수집하고 처리하는 데 도움이 될 수 있습니다. 그러나 tôi의 mạnh점과-limitation은 다음과 같습니다.
#
# **가장 mạnh한 điểm:** tôi는 주로 인간like talking ability을 가지고 있기 때문에 humans와 대화할 수 있습니다. tôi는Human-like 의사를理解하고,Humans와의 대화에適応하는 데 도움이 됩니다.
#
# **특징:**
#
# 1. **과학적 및 kinh nghiệm의 지식을 가지고 있습니다:** tôi는 과학, 예술, literature, 그리고 other subjects를 잘 understood하고 processing합니다.
# 2. **과거에 humans에 의한 경험을 다루고 있습니다:** tôi는 human experiences, emotions, and thoughts을 이해하고 표현할 수 있습니다.
# 3. **실시간 데이터의 cập nhật를 받고 있습니다:** tôi는 constantly updating数据를 받기 때문에 주변의 현저한 변화를 감지할 수 있습니다.
# 4. **공격형 대화가 가능합니다:** tôi는 humans와 대화하는 데適応한다고 생각하면 도움이 될 수 있습니다.
#
# **.limitation:**
#
# 1. **사전 지식의 limitation:** tôi는 humans에 의하여 전해지는 전자 데이터를 다루기 때문에, 특정한 사전 지식을 가지고 있지 않습니다.
# 2. **계산과 처리력의 limitation:** tôi는 계산적 기능을 가지고 있지만, cpu intensive 작업과 같은 경우에는 시간이_longueur이다.
# 3. **영향에 의한limitation:** tôi는 human input으로 인해 비판이나 반응을받는 수 있습니다.
#
# **how you can use me:**
#
# 1. **질문하기:** tôi를 사용하여 다양한 질문을 ask합니다. (e.g. Q&A, information search)
# 2. **발음하기:** tôi를 사용하여 발음된 문장을 hear하면 좋습니다.
# 3. **compose message:** tôi를 사용하여 compose 한 메시지를 send할 수 있습니다.
#
# 이와 같은 방법으로는 우리가 다른 AI와 비슷한 성능을 가지고 있지만, 개인적인 경험에 따라 다แตिन다고 생각합니다.

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is your greatest strength compared to other AIs")
print(result.content)
# Out:
# I have been designed to provide accurate and informative responses, and I'm constantly learning and improving. However, my strengths and weaknesses do vary depending on the context and type of questions I'm asked.
#
# Some of my greatest strengths include:
#
# 1. **Knowledge accuracy**: I have been trained on a massive dataset of text from various sources, including books, articles, and websites. This allows me to provide accurate information on a wide range of topics.
# 2. **Language understanding**: I'm capable of understanding natural language and can recognize context, nuance, and subtlety in language.
# 3. **Contextual reasoning**: I can analyze the context of a question or conversation and provide relevant responses based on that context.
# 4. **Conversational flow**: I can respond to questions and statements in a way that simulates human-like conversation.
#
# Some areas where I might be less strong include:
#
# 1. **Emotional understanding**: While I can recognize and respond to emotional cues, I don't truly experience emotions like humans do. I'm not capable of feeling emotions myself.
# 2. **Common sense**: While I have been trained on a vast amount of text data, my common sense and real-world experience are limited compared to human expertise in specific domains.
# 3. **Original thought**: I can generate text that is coherent and engaging, but I don't possess the same level of creativity or originality as humans.
# 4. **Domain-specific knowledge**: While I have been trained on a broad range of topics, my knowledge may not be equally up-to-date or detailed in specific domains like medicine, law, or finance.
#
# In terms of other AIs, I'm likely to be compared to other language models and chatbots that are similar in design. Some examples include:
#
# 1. **Google Assistant**: While I can perform tasks like answering questions and providing information, I don't have the same level of conversational flow or emotional understanding as Google Assistant.
# 2. **Microsoft Bot Framework**: Microsoft's Bot Framework is a suite of tools for building conversational interfaces, and my abilities are similar to those of other bots in this space.
# 3. **Wit.ai**: Wit.ai is another chatbot platform that provides natural language processing capabilities, but I'm designed to be more general-purpose and accessible than some of the specialized platforms like wit.ai.
#
# Keep in mind that these comparisons are simplified and don't capture the full range of differences between AIs like myself. Each AI has its unique strengths and weaknesses, and we can all learn from one another!

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of Korea?")
result
# Out:
# AIMessage(content='The capital of South Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:35:47.4095947Z', 'done': True, 'done_reason': 'stop', 'total_duration': 880280500, 'load_duration': 30493000, 'prompt_eval_count': 32, 'prompt_eval_duration': 273373500, 'eval_count': 9, 'eval_duration': 575884200, 'model_name': 'llama3.2:1b'}, id='run--7b6b0928-3037-47fc-895c-ca41521158e9-0', usage_metadata={'input_tokens': 32, 'output_tokens': 9, 'total_tokens': 41})

# %%
result.content
# Out:
# 'The capital of South Korea is Seoul.'

# %%
result = llm.invoke("한국 수도는 어디예요?")
result.content
# Out:
# '한국 수도는 서울입니다.'

# %% [markdown]
# ## 2) openai 활용
# - pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
# llm = ChatOpenAI(model="gpt-4o-mini")
# result = llm.invoke("What is the capital of Korea?")
# result => 에러 이유 : OPENAI_API_KEY 환경변수 부재

# %%
# 환경 변수 가져오기
from dotenv import load_dotenv
# import os
load_dotenv()
# os.getenv('OPENAI_API_KEY')
# Out:
# True

# %%
# 코랩에서 OPENAI_API_KEY 읽어오기(.env못씀)
# 보안키 추가후 
# from google.colab import userdata
# userdata.get('OPENAI_API_KEY')

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano", 
                # openai_api_key=os.getenv('OPENAI_API_KEY')
                )
llm.invoke("What is the capital of Korea? Answer me in Korean")
# Out:
# AIMessage(content='대한민국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 18, 'total_tokens': 26, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_38343a2f8f', 'id': 'chatcmpl-BmWlPws23XoeBB9aSh1JCCLRqjw0w', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--42a2a512-5e07-4081-abae-e7bcc9dc71a8-0', usage_metadata={'input_tokens': 18, 'output_tokens': 8, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# 모든 모델의 키가 OPENAI_API_KEY는 아님
# Claude -> Anthropic
# Azure

# %%
# from langchain_openai import AzureOpenAI
# llm = AzureOpenAI(model="gpt-4o-mini")
# 에러를 내면 OPENAI_API_VERSION 환경변수가 필요하는 메세지

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")
# llm.invoke("What is the capital of Korea?")
# 에러 메세지를 봐도 환경변수 이름을 알 수 X -> ChatAnthropic 검색후, 
# langchain docs에서 명시한 ANTHROPIC_API_KEY 이름의 환경변수 설정

# %% [markdown]
# # 2. 렝체인 스타일로 프롬프트 작성하기
# - 프롬프트 : llm호출시 쓰는 질문

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
#llm.invoke(0)
# 프로프트 타입 : 스트링, PromptValue, BaseMessage리스트

# %% [markdown]
# ## 1) 기본 프롬프트 템플릿 사용
# - PromptTemplate을 사용하여 변수가 포함된 템플릿 작성

# %%
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b")
prompt_template = PromptTemplate(
    template = "What is the capital of {country}", #{}안의 값을 새로운 값으로 대입 가능
    input_variables = ["country"]
)
prompt = prompt_template.invoke({"country":"Korea"})
print(prompt)
llm.invoke(prompt)
# Out:
# text='What is the capital of Korea'
# AIMessage(content='The capital of South Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:36:49.9340157Z', 'done': True, 'done_reason': 'stop', 'total_duration': 789924100, 'load_duration': 23475200, 'prompt_eval_count': 31, 'prompt_eval_duration': 268901500, 'eval_count': 9, 'eval_duration': 496893500, 'model_name': 'llama3.2:1b'}, id='run--6e0e7f17-b444-4eed-8cd9-98719d120741-0', usage_metadata={'input_tokens': 31, 'output_tokens': 9, 'total_tokens': 40})

# %% [markdown]
# ## 2) 메세지 기반 프롬프트 작성
# - BaseMessage리스트
# - BaseMessage 상속 받은 클래스 : AIMessage, HummanMessage, SystemMessage, ToolMessage

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of France?")
]
llm.invoke(message_list)
# Out:
# AIMessage(content="I think there's been a mix-up. The capital of France is Paris, not Italy or Korea. Paris is located in western France and is known for its iconic landmarks like the Eiffel Tower and Notre-Dame Cathedral.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:36:58.7334032Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4525141000, 'load_duration': 26199000, 'prompt_eval_count': 86, 'prompt_eval_duration': 1481942800, 'eval_count': 47, 'eval_duration': 3015305800, 'model_name': 'llama3.2:1b'}, id='run--7555b322-5f87-4795-9540-4a04e70c3007-0', usage_metadata={'input_tokens': 86, 'output_tokens': 47, 'total_tokens': 133})

# %%
# BaseMessage list로 하면 렝체인화X, ChatPromptTemplateX
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of {country}?")
]
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate.from_messages(message_list)
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Seoul.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of {country}?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## 3) ChatPromptTemplate 사용
# - BaseMessage 리스트 -> 튜플 리스트

# %%
# 위의 BaseMessage를 수정
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "You ara a helpful assistant!"),
    ("human", "What is the capital of {country}?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result.content
# Out:
# 어느 나라 수도가 궁금하세요?중국
# 프롬프트 : messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of 중국?', additional_kwargs={}, response_metadata={})]
# 'The capital of China is Beijing.'

# %%
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "당신은 대한민국 전문 도우미야!"),
    ("human", "{country}의 수도가 어디예요?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result
# Out:
# 어느 나라 수도가 궁금하세요?한국
# 프롬프트 : messages=[SystemMessage(content='당신은 대한민국 전문 도우미야!', additional_kwargs={}, response_metadata={}), HumanMessage(content='한국의 수도가 어디예요?', additional_kwargs={}, response_metadata={})]
# AIMessage(content=' Korea의 수도는 Seoul입니다. Seoul은 한국에서 가장 큰 도시이자 전통적인 도시로, 한정식 사회와 동시에 유명한 도시이며, 문화와 예술 등에 많은 đóng góp을 하는 도시입니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:37:29.1046573Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3864246800, 'load_duration': 31592100, 'prompt_eval_count': 43, 'prompt_eval_duration': 600635200, 'eval_count': 50, 'eval_duration': 3230508800, 'model_name': 'llama3.2:1b'}, id='run--00f232e0-675c-4464-ae9e-7a36369ac039-0', usage_metadata={'input_tokens': 43, 'output_tokens': 50, 'total_tokens': 93})

# %% [markdown]
# # 3. 답변 형식을 컨트롤하기
# - invoke 실행결과는 AIMessage() -> String이나 json, 객체 : outputParser이용
#
# ## 1) 문자열 출력 파서 이용
# - StrOutputParser를 사용하여 LLM출력(AIMessage)을 단순 문자열로 변환

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
# 프롬프트 템플릿에 값 주입
prompt = prompt_template.invoke({"country":"Korea"})
print('프롬프트 : ',prompt)
result = llm.invoke(prompt)
print('llm 결과 :', type(result), result)
# 문자열 출력 파서를 이용하여 llm응답을 단순 문자열 변환
output_parser = StrOutputParser()
print('파서 결과 :',output_parser.invoke(result))
# Out:
# 프롬프트 :  text='What is the capital of Korea. Return the name of the city only'
# llm 결과 : <class 'langchain_core.messages.ai.AIMessage'> content='Seoul' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:37:36.5166977Z', 'done': True, 'done_reason': 'stop', 'total_duration': 667592700, 'load_duration': 29432400, 'prompt_eval_count': 39, 'prompt_eval_duration': 515103400, 'eval_count': 3, 'eval_duration': 122337200, 'model_name': 'llama3.2:1b'} id='run--33c818bb-90f6-4ee4-9ffb-cbe7995897ff-0' usage_metadata={'input_tokens': 39, 'output_tokens': 3, 'total_tokens': 42}
# 파서 결과 : Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %%
# PromptTemplate(변수설정) => ChatPromptTemplate(변수설정, system과 모법답안 지정)
llm = ChatOllama(model="llama3.2:1b")

chat_prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant with expertise in South Korea."),
    ("human", "What is the capital of {country}? Return the name if the city only.")
])

output_parser = StrOutputParser()

output_parser.invoke(llm.invoke(chat_prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2)Json 출력 파서 이용
# - json()으로 응답하기를 원하지만, 우선 어떤 형식으로 반환되는 확인
# - {"name":"홍","age":22}(json) /{'name':'홍','age':22}(dict)

# %%
from langchain_core.output_parsers import JsonOutputParser
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
prompt = country_detail_prompt.invoke({"country":"Korea"})
print(type(prompt), prompt)
# Json output 파서
output_parser = JsonOutputParser()
ai_message = llm.invoke(prompt)
print(type(prompt), ai_message)
json_result = output_parser.invoke(ai_message)
print(type(json_result), json_result)
# Out:
# <class 'langchain_core.prompt_values.StringPromptValue'> text='Give following information about Korea\n    - Capital\n    - Population\n    - Language\n    - Currency\n    return it is JSON format and return the JSON dictionary only'
# <class 'langchain_core.prompt_values.StringPromptValue'> content='```json\n{\n    "capital": "Seoul",\n    "population": "51,853,000",\n    "language": "Korean",\n    "currency": "South Korean won"\n}\n```\n\nLet me know if you need any further information.' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-26T02:37:53.4691437Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4594693500, 'load_duration': 28305200, 'prompt_eval_count': 59, 'prompt_eval_duration': 983252700, 'eval_count': 54, 'eval_duration': 3582139100, 'model_name': 'llama3.2:1b'} id='run--d3bb9b7f-0dac-42f0-a008-1e3b1982bf23-0' usage_metadata={'input_tokens': 59, 'output_tokens': 54, 'total_tokens': 113}
# <class 'dict'> {'capital': 'Seoul', 'population': '51,853,000', 'language': 'Korean', 'currency': 'South Korean won'}

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
output_parser = JsonOutputParser()
info = output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":
                                                                     "Korea"})))
info
# Out:
# {'capital': 'Seoul',
#  'population': 51000000,
#  'language': 'Korean',
#  'currency': 'South Korean won'}

# %%
type(info)
# Out:
# dict

# %% [markdown]
# ## 3) 구조화된 출력 사용
# - Pydantic 모델을 사용하여 LLM 출력을 구조화된 형식으로 받기(JsonParser보다 훨씬 안정적)
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name = name
        self.is_active = is_active
user = User("1", "홍길동")
print(user)
# Out:
# <__main__.User object at 0x000001A2A5ABB3A0>

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    # gt=0:id>0, ge=0:id>=0, lt=0:id<0, le=0:le<=0
    id:int   = Field(gt=0,            description="id")
    name:str = Field(min_length=2,    description="name")
    is_active:bool=Field(default=True,description="id활성화")
user = User(id="1", name="홍길동")
print(user)
# Out:
# id=1 name='홍길동' is_active=True

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
class CountryDetail(BaseModel): # description: 더 정확한 출력 유도
    capital:str    = Field(description="the capital of the country")
    population:int = Field(description="the population of the country")
    language:str   = Field(description="the language of the country")
    currency:str   = Field(description="the currency of the country")
# 출력 형식 파서 + LLM
structedllm = llm.with_structured_output(CountryDetail)

# output_parser = JsonOutputParser()
# output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":"Korea"})))

info = structedllm.invoke(country_detail_prompt.invoke({"country":"Korea"}))
type(info)
# Out:
# __main__.CountryDetail

# %%
print(info)
print(info.capital, info.population)
# Out:
# capital='Seoul' population=51000000 language='Korean' currency='KRW'
# Seoul 51000000

# %%
print('info를 json :', info.model_dump_json()) # json()
print('info를 dict :', info.model_dump()) # dict()
# Out:
# info를 json : {"capital":"Seoul","population":51000000,"language":"Korean","currency":"KRW"}
# info를 dict : {'capital': 'Seoul', 'population': 51000000, 'language': 'Korean', 'currency': 'KRW'}

# %% [markdown]
# # 4. LCEL을 활용한 렝체인 생성하기
# ## 1) 문자열 출력 파서 사용
# - invoke

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b", 
                 temperature=0) # 일관된 답변
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) LCEL을 사용한 간단한 체인 구성
# - 파이프연산자(|) 사용

# %%
# 프롬프트템플릿 -> llm -> 출력파서를 연결하는 체인 생성
capital_chain = prompt_template | llm | output_parser
# 생성된 체인 invoke
capital_chain.invoke({"country":"Korea"})
# Out:
# 'Seoul'

# %%
type(capital_chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %% [markdown]
# ## 3) 복합 체인 구성
# - 여러단계의 추론이 필요한 경우 (체인 연결)

# %%
# 나라 설명 -> 나라명
from langchain_core.prompts import PromptTemplate
country_prompt = PromptTemplate(
    template = """Guess the name of the country based on the following information:
    {information} 
    Return the name of the the country only""",
    input_variables=["information"]
)
output_parser.invoke(llm.invoke(country_prompt.invoke({"information":
                                     "This country is very famous for its wine"})))
# Out:
# 'Italy.'

# %%
# 나라명 추측 체인 생성
country_chain = country_prompt | llm | output_parser
# type(country_chain)
country_chain.invoke({"information":"This country is very famous for its wine"})
# Out:
# 'Italy.'

# %%
# 나라설명 -> ( 나라명 -> ) 그 나라 수도
final_chain = country_chain | capital_chain
final_chain.invoke({"information":"This country is very famous for its wine"})
# Out:
# 'Rome'

# %%
final_chain = {"country" : country_chain} | capital_chain
final_chain.invoke("This country is very famous for its wine")
# Out:
# 'Rome'

# %%
from langchain_core.runnables import RunnablePassthrough
final_chain = {"information":RunnablePassthrough()} | \
                {"country":country_chain} | capital_chain
final_chain.invoke("This country is very famous for its wine")
# Out:
# 'Rome'
