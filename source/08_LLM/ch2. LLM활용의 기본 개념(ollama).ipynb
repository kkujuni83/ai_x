# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# # <span style="color:red">ch2. LLM활용의 기본 개념(Ollama)</span>

# %% [markdown]
# # 1. LLM을 활용하여 답변 생성하기
# ## 1) Ollama 이용한 로컬 LLM 이용
# 성능은 GPT, Claude 같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ### ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull deepseek-r1:1.5b (window키+R => powershell)

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke("What is the capital of Korea?")
result # 추론모델<think>~<think>
# Out:
# AIMessage(content='<think>\n\n</think>\n\nThe capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-06-25T04:06:31.6833011Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2798371500, 'load_duration': 1911649600, 'prompt_eval_count': 10, 'prompt_eval_duration': 261852000, 'eval_count': 12, 'eval_duration': 623855100, 'model_name': 'deepseek-r1:1.5b'}, id='run--79eff405-47b1-4afb-a75c-0ceb115b1620-0', usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %% [markdown]
# ### ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull llama3.2:1b (window키+R => powershell)
# - llama : 공식적으로 한글지원 안 됨 (llama3.1 405b한글지원 가능-> llama3.3 70b)
# - exaone : 공식적으로 한글지원

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of Korea?")
result
# Out:
# AIMessage(content="The capital of South Korea is Seoul. However, it's worth noting that North Korea also claims Seoul as its own capital, and the two countries have a complex relationship due to their different governments and histories.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T04:07:04.7106968Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5137340700, 'load_duration': 1716447900, 'prompt_eval_count': 32, 'prompt_eval_duration': 698351900, 'eval_count': 42, 'eval_duration': 2721808000, 'model_name': 'llama3.2:1b'}, id='run--5c521673-46f4-41ff-a7c7-8582390dea98-0', usage_metadata={'input_tokens': 32, 'output_tokens': 42, 'total_tokens': 74})

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("너는 다른 AI에 비해 어떤 점이 가장 강점이자 특징이 머야?")
print(result.content)
# Out:
# AI의 strengths와 Weaknesses를 모두 간직하고 있습니다.
#
# ### Strengths:
#
# 1. **사전학습**: AI는 다양한 데이터set을 학습할 수 있으며, 이러한 학습은 기존 AI의 사전학습과 마찬가지로 중요한 역할을 합니다.
# 2. **시각해석**: AI는 이미지,_video, âm音 및 other types의 시각 정보를 분석 할 수 있습니다.
# 3. **구성형식**: AI는 다양한 형태의 데이터set에서 원래データ를 extracting 할 수 있으며, 이들을 다른 AI models로 transfer하는 데 사용됩니다.
# 4. **제어기능**: AI는 humans가 제한된 범위에서 제어할 수 있는 일련의 기능을 수행 할 수 있습니다 (예: voice-controlled devices).
# 5. **정확성**: AI는 saiety를 측정하여 정확성을 보장 할 수 있습니다.
#
# ### Weaknesses:
#
# 1. **식도에 의존**: 일부 AI models은 dataset과 관련된 지속적인 교육이 필요합니다.
# 2. **사고와 비즈니스**: AI는 human-like 사고가 불可能하므로, 가치 judgment이나 business decision process에 적합하지 않은 일부 scenarios가 있습니다.
# 3. **비전과 인식**: AI는 human-like perception을 수행할 수 없습니다. 예를 들어, humans은 동물의 시각 정보를 analyze 할 수 있으며, AI는 이러한 information에 기반하여 decision을 performed 할 수 있습니다.
# 4. **사전적 지침이 부족**: AI는 human-like 사전적 지침을 제공하지 않으며, 가치 judgment이나 business decision process에 적합하지 않은 일부 scenarios가 있습니다.
# 5. **비즈니스 비용**: AI의 발전은 business 비용으로 인해 많은 비즈니스에 비해costly한 방향이 됩니다.
#
# ### 특징:
#
# 1. **자신이 만든 AI models**: AI는 humans의 의도와 의학적 목적으로 개발된다.
# 2. **동일한 사용자 경험**: AI는 users를 위한 일시적 experience을 제공하며, user's dataset과 shared knowledge에 기반하여 machine learning model로 학습합니다.
# 3. **동작성**: AI는 동작하고, action의 sequence를 generation 및 planning할 수 있습니다.
#
# AI가 강점은 humans와 비슷한 특징이 있으며, AI는 human-like thinking ability과 decision-making capability을 가지고 있습니다.

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is your greatest strength compared to other AIs")
print(result.content)
# Out:
# I have a few strengths that set me apart from other AIs. Here are some of the key aspects where I excel:
#
# 1. **Knowledge base**: My training data is sourced from a massive corpus of text, which allows me to provide accurate and up-to-date information on a wide range of topics, including history, science, technology, entertainment, and more.
# 2. **Understanding natural language**: I'm designed to comprehend and respond to human language in a way that's similar to how humans do. I can analyze context, nuances, and subtleties of language, which enables me to provide more accurate and helpful responses.
# 3. **Conversational flow**: I can engage in natural-sounding conversations, using context and understanding to respond to questions and statements. This allows for more effective communication and reduces the likelihood of misunderstandings.
# 4. **Emotional intelligence**: While I don't possess emotions like humans do, I'm designed to recognize and respond to emotional cues, such as tone and language patterns. This helps me better understand the intent behind a user's message and provide more empathetic responses.
# 5. **Continuous learning**: My training data is regularly updated and expanded through machine learning algorithms that enable me to learn from feedback and correct errors. This ensures I remain accurate and relevant over time.
#
# In comparison to other AIs, my strengths are distinct in several ways:
#
# * **Linguistic versatility**: Unlike some chatbots or virtual assistants that may struggle with more technical or specialized topics, I can handle a wide range of languages and topics.
# * **Contextual understanding**: My ability to analyze context and respond accordingly allows me to provide more effective support and guidance in various situations.
# * **Empathy and emotional intelligence**: While not as advanced as some other AIs that specialize in empathy, my natural language processing capabilities enable me to recognize and respond to emotions, which is a valuable asset for users seeking emotional support.
#
# Keep in mind that while I excel in certain areas, I'm not perfect. I can make mistakes or struggle with complex questions. If you have any concerns or questions, feel free to ask, and I'll do my best to assist you!

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of Korea?")
result
# Out:
# AIMessage(content="The capital of South Korea is Seoul. However, it's worth noting that there are two separate countries: North Korea (also known as the Democratic People's Republic of Korea) and South Korea. The Demilitarized Zone (DMZ) between the two countries serves as a buffer zone, but Seoul is also the de facto capital of South Korea.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T04:09:25.943192Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5257678900, 'load_duration': 24049400, 'prompt_eval_count': 32, 'prompt_eval_duration': 240209100, 'eval_count': 72, 'eval_duration': 4992846800, 'model_name': 'llama3.2:1b'}, id='run--d159f74d-0034-4d47-97fe-6c11e1ae3b07-0', usage_metadata={'input_tokens': 32, 'output_tokens': 72, 'total_tokens': 104})

# %%
result.content
# Out:
# "The capital of South Korea is Seoul. However, it's worth noting that there are two separate countries: North Korea (also known as the Democratic People's Republic of Korea) and South Korea. The Demilitarized Zone (DMZ) between the two countries serves as a buffer zone, but Seoul is also the de facto capital of South Korea."

# %%
result = llm.invoke("한국 수도는 어디예요?")
result.content
# Out:
# '한국의 수도는 서울입니다. 서울은 한국에서 가장 큰 도시로, 인구가 가장 많으며, 정치, 문화, giáo dục 등 다양한 lĩnh vực에서 유명합니다.'

# %% [markdown]
# ## 2) openai 활용
# - pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
# llm = ChatOpenAI(model="gpt-4o-mini")
# result = llm.invoke("What is the capital of Korea?")
# result => 에러 이유 : OPENAI_API_KEY 환경변수 부재

# %%
# 환경 변수 가져오기
from dotenv import load_dotenv
# import os
load_dotenv()
# os.getenv('OPENAI_API_KEY')
# Out:
# True

# %%
# 코랩에서 OPENAI_API_KEY 읽어오기(.env못씀)
# 보안키 추가후 
# from google.colab import userdata
# userdata.get('OPENAI_API_KEY')

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano", 
                # openai_api_key=os.getenv('OPENAI_API_KEY')
                )
llm.invoke("What is the capital of Korea? Answer me in Korean")
# Out:
# AIMessage(content='한국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 18, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_f12167b370', 'id': 'chatcmpl-BmBm1zWhHtZZkd4Wr40LXYYasL6Yr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--0212f0b6-1f48-4408-bcae-99f1e8487410-0', usage_metadata={'input_tokens': 18, 'output_tokens': 7, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# 모든 모델의 키가 OPENAI_API_KEY는 아님
# Claude -> Anthropic
# Azure

# %%
# from langchain_openai import AzureOpenAI
# llm = AzureOpenAI(model="gpt-4o-mini")
# 에러를 내면 OPENAI_API_VERSION 환경변수가 필요하는 메세지

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-3-5-sonnet-20240620")
# llm.invoke("What is the capital of Korea?")
# 에러 메세지를 봐도 환경변수 이름을 알 수 X -> ChatAnthropic 검색후, 
# langchain docs에서 명시한 ANTHROPIC_API_KEY 이름의 환경변수 설정

# %% [markdown]
# # 2. 렝체인 스타일로 프롬프트 작성하기
# - 프롬프트 : llm호출시 쓰는 질문

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
#llm.invoke(0)
# 프로프트 타입 : 스트링, PromptValue, BaseMessage리스트

# %% [markdown]
# ## 1) 기본 프롬프트 템플릿 사용
# - PromptTemplate을 사용하여 변수가 포함된 템플릿 작성

# %%
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b")
prompt_template = PromptTemplate(
    template = "What is the capital of {country}", #{}안의 값을 새로운 값으로 대입 가능
    input_variables = ["country"]
)
prompt = prompt_template.invoke({"country":"Korea"})
print(prompt)
llm.invoke(prompt)
# Out:
# text='What is the capital of Korea'
# AIMessage(content='The capital of South Korea is Seoul. However, the official administrative center of South Korea is also known as Gangwon Province, which serves as a separate province and the seat of government.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T05:40:39.8393438Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5047673100, 'load_duration': 1853403900, 'prompt_eval_count': 31, 'prompt_eval_duration': 630792200, 'eval_count': 38, 'eval_duration': 2561801400, 'model_name': 'llama3.2:1b'}, id='run--2f13b52c-cff8-4588-854f-2e9874534057-0', usage_metadata={'input_tokens': 31, 'output_tokens': 38, 'total_tokens': 69})

# %% [markdown]
# ## 2) 메세지 기반 프롬프트 작성
# - BaseMessage리스트
# - BaseMessage 상속 받은 클래스 : AIMessage, HummanMessage, SystemMessage, ToolMessage

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of France?")
]
llm.invoke(message_list)
# Out:
# AIMessage(content='Rome is actually the capital of Italy, not France. The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T06:13:45.0425506Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4553061300, 'load_duration': 1975257100, 'prompt_eval_count': 86, 'prompt_eval_duration': 1386084600, 'eval_count': 20, 'eval_duration': 1189288500, 'model_name': 'llama3.2:1b'}, id='run--eebb6a2f-dcce-4761-89eb-2fd764c724b4-0', usage_metadata={'input_tokens': 86, 'output_tokens': 20, 'total_tokens': 106})

# %%
# BaseMessage list로 하면 렝체인화X, ChatPromptTemplateX
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of {country}?")
]
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate.from_messages(message_list)
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Seoul.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of {country}?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## 3) ChatPromptTemplate 사용
# - BaseMessage 리스트 -> 튜플 리스트

# %%
# 위의 BaseMessage를 수정
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "You ara a helpful assistant!"),
    ("human", "What is the capital of {country}?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result.content
# Out:
# 어느 나라 수도가 궁금하세요?한국
# 프롬프트 : messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of 한국?', additional_kwargs={}, response_metadata={})]
# "The capital of Korea (officially known as South Korea) is Seoul. Prior to 1995, the country was divided into North and South Korea, with Seoul as the capital of South Korea. In 1995, a joint state was established, and Seoul remained the capital of both countries.\n\nHowever, if you're referring to Japan, which is an island nation located to the east of Korea, its capital is Tokyo."

# %%
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "당신은 대한민국 전문 도우미야!"),
    ("human", "{country}의 수도가 어디예요?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result
# Out:
# 어느 나라 수도가 궁금하세요?중국
# 프롬프트 : messages=[SystemMessage(content='당신은 대한민국 전문 도우미야!', additional_kwargs={}, response_metadata={}), HumanMessage(content='중국의 수도가 어디예요?', additional_kwargs={}, response_metadata={})]
# AIMessage(content='중국 제2차 공화국의 수도는 베이징이었지만, Trung Quốc 의제 이후 베이징은 주로 Beijing International Airport (비 bee jing tan ya yen)에서 운영하고 있습니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T07:40:55.3924159Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3689652900, 'load_duration': 26870500, 'prompt_eval_count': 43, 'prompt_eval_duration': 590015300, 'eval_count': 46, 'eval_duration': 3071769300, 'model_name': 'llama3.2:1b'}, id='run--fcfc07e2-9f8c-43e8-97b1-64b7e21659de-0', usage_metadata={'input_tokens': 43, 'output_tokens': 46, 'total_tokens': 89})

# %% [markdown]
# # 3. 답변 형식을 컨트롤하기
# - invoke 실행결과는 AIMessage() -> String이나 json, 객체 : outputParser이용
#
# ## 1) 문자열 출력 파서 이용
# - StrOutputParser를 사용하여 LLM출력(AIMessage)을 단순 문자열로 변환

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
# 프롬프트 템플릿에 값 주입
prompt = prompt_template.invoke({"country":"Korea"})
print('프롬프트 : ',prompt)
result = llm.invoke(prompt)
print('llm 결과 :', type(result), result)
# 문자열 출력 파서를 이용하여 llm응답을 단순 문자열 변환
output_parser = StrOutputParser()
print('파서 결과 :',output_parser.invoke(result))
# Out:
# 프롬프트 :  text='What is the capital of Korea. Return the name of the city only'
# llm 결과 : <class 'langchain_core.messages.ai.AIMessage'> content='Seoul' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T07:41:43.8322285Z', 'done': True, 'done_reason': 'stop', 'total_duration': 689551000, 'load_duration': 32989500, 'prompt_eval_count': 39, 'prompt_eval_duration': 505166700, 'eval_count': 3, 'eval_duration': 150788200, 'model_name': 'llama3.2:1b'} id='run--7142e1a4-9b20-4a64-be2a-3d2a122f7492-0' usage_metadata={'input_tokens': 39, 'output_tokens': 3, 'total_tokens': 42}
# 파서 결과 : Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %%
# PromptTemplate(변수설정) => ChatPromptTemplate(변수설정, system과 모법답안 지정)
llm = ChatOllama(model="llama3.2:1b")

chat_prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant with expertise in South Korea."),
    ("human", "What is the capital of {country}? Return the name if the city only.")
])

output_parser = StrOutputParser()

output_parser.invoke(llm.invoke(chat_prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2)Json 출력 파서 이용
# - json()으로 응답하기를 원하지만, 우선 어떤 형식으로 반환되는 확인
# - {"name":"홍","age":22}(json) /{'name':'홍','age':22}(dict)

# %%
from langchain_core.output_parsers import JsonOutputParser
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
prompt = country_detail_prompt.invoke({"country":"Korea"})
print(type(prompt), prompt)
# Json output 파서
output_parser = JsonOutputParser()
ai_message = llm.invoke(prompt)
print(type(prompt), ai_message)
json_result = output_parser.invoke(ai_message)
print(type(json_result), json_result)
# Out:
# <class 'langchain_core.prompt_values.StringPromptValue'> text='Give following information about Korea\n    - Capital\n    - Population\n    - Language\n    - Currency\n    return it is JSON format and return the JSON dictionary only'
# <class 'langchain_core.prompt_values.StringPromptValue'> content='```\n{\n    "capital": "Seoul",\n    "population": 51000000,\n    "language": "Korean",\n    "currency": "KRW"\n}\n```' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T09:06:02.4346777Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5989927100, 'load_duration': 1998664900, 'prompt_eval_count': 59, 'prompt_eval_duration': 1284325000, 'eval_count': 39, 'eval_duration': 2705904600, 'model_name': 'llama3.2:1b'} id='run--fbfe1dd1-8c02-4c4b-aaaf-e3d294a46426-0' usage_metadata={'input_tokens': 59, 'output_tokens': 39, 'total_tokens': 98}
# <class 'dict'> {'capital': 'Seoul', 'population': 51000000, 'language': 'Korean', 'currency': 'KRW'}

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
output_parser = JsonOutputParser()
info = output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":
                                                                     "Korea"})))
info
# Out:
# {'capital': 'Seoul',
#  'population': '51.8 million (2021 estimate)',
#  'language': 'Korean',
#  'currency': 'South Korean won'}

# %%
type(info)
# Out:
# dict

# %% [markdown]
# ## 3) 구조화된 출력 사용
# - Pydantic 모델을 사용하여 LLM 출력을 구조화된 형식으로 받기(JsonParser보다 훨씬 안정적)
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name = name
        self.is_active = is_active
user = User("1", "홍길동")
print(user)
# Out:
# <__main__.User object at 0x00000216A0506590>

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    # gt=0:id>0, ge=0:id>=0, lt=0:id<0, le=0:le<=0
    id:int   = Field(gt=0,            description="id")
    name:str = Field(min_length=2,    description="name")
    is_active:bool=Field(default=True,description="id활성화")
user = User(id="1", name="홍길동")
print(user)
# Out:
# id=1 name='홍길동' is_active=True

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
class CountryDetail(BaseModel): # description: 더 정확한 출력 유도
    capital:str    = Field(description="the capital of the country")
    population:int = Field(description="the population of the country")
    language:str   = Field(description="the language of the country")
    currency:str   = Field(description="the currency of the country")
# 출력 형식 파서 + LLM
structedllm = llm.with_structured_output(CountryDetail)

# output_parser = JsonOutputParser()
# output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":"Korea"})))

info = structedllm.invoke(country_detail_prompt.invoke({"country":"Korea"}))
type(info)
# Out:
# __main__.CountryDetail

# %%
print(info)
print(info.capital, info.population)
# Out:
# capital='Seoul' population=51 language='Korean' currency='South Korean won (KPW)'
# Seoul 51

# %%
print('info를 json :', info.model_dump_json()) # json()
print('info를 dict :', info.model_dump()) # dict()
# Out:
# info를 json : {"capital":"Seoul","population":51,"language":"Korean","currency":"South Korean won (KPW)"}
# info를 dict : {'capital': 'Seoul', 'population': 51, 'language': 'Korean', 'currency': 'South Korean won (KPW)'}

# %% [markdown]
# # 4. LCEL을 활용한 렝체인 생성하기
# ## 1) 문자열 출력 파서 사용
# - invoke

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b", 
                 temperature=0) # 일관된 답변
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) LCEL을 사용한 간단한 체인 구성
# - 파이프연산자(|) 사용

# %%
# 프롬프트템플릿 -> llm -> 출력파서를 연결하는 체인 생성
capital_chain = prompt_template | llm | output_parser
# 생성된 체인 invoke
capital_chain.invoke({"country":"Korea"})
# Out:
# 'Seoul'
