# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# ## 1. 환경(패키지 및 환경변수)
# - pip install langchain-upstage

# %%
# %pip install -q langchain-upstage
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 2. LLM 답변 생성
# ### 2.1 OpenAI SDK를 사용

# %%
from openai import OpenAI # openai==1.52.2
import os
upstage_api_key = os.getenv("UPSTAGE_API_KEY")

client = OpenAI(
    api_key=upstage_api_key,
    base_url="https://api.upstage.ai/v1"
)
stream = client.chat.completions.create(
    model="solar-pro2",
    messages=[
        {
            "role": "user",
            "content": "2020년 월드 시리즈 누가 우승했어?"
        }
    ],
    stream=False,
)

# %%
print(stream.choices[0].message.content)
# Out:
# 2020년 월드 시리즈에서는 **로스앤젤레스 다저스**가 우승했습니다.
#
# - **상대 팀**: 탬파베이 레이스
# - **시리즈 결과**: 4승 2패로 다저스 승리
# - **MVP**: 다저스의 투수 **코리 시거**(Corey Seager, 당시 포지션은 세컨드 베이스)
#
# 이 시리즈는 코로나19 영향으로 무관중 경기로 진행되었으며, 다저스는 프랭크라인 월리스 구단주 시대 이후 첫 우승을 달성했습니다. 또한, 1988년 이후 32년 만의 월드 시리즈 우승이었습니다.

# %% [markdown]
# ### 2.2 LangChain을 선택
# - 발급받은 API Key를 .env에 UPSTAGE_API_KEY라고 저장하면 별도의 설정없이 ChatUpstage를 바로 사용

# %%
from langchain_upstage import ChatUpstage
from langchain_core.messages import SystemMessage, HumanMessage
llm = ChatUpstage()
messages = [
    SystemMessage(content="너는 친절하게 대답해 주는 비서야"),
    HumanMessage(content="2020년 월드 시리즈 누가 우승했어?")
]
ai_message = llm.invoke(input=messages)
ai_message
# Out:
# AIMessage(content='2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 그들의 7번째 월드 시리즈 타이틀이며, 1988년 이후 32년 만의 우승이었습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 우승을 차지했습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 36, 'total_tokens': 102, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '974ba5bd-8452-44f5-8cef-be4f3adc369a', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--2fc4d014-6755-42b3-ad41-411cd69c8e5d-0', usage_metadata={'input_tokens': 36, 'output_tokens': 66, 'total_tokens': 102, 'input_token_details': {}, 'output_token_details': {}})

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 이는 그들의 7번째 월드 시리즈 타이틀이며, 1988년 이후 32년 만의 우승이었습니다. 그들은 탬파베이 레이스를 4승 2패로 꺾고 우승을 차지했습니다.'
