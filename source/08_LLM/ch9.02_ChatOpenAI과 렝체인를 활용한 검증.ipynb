# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# ##1. 환경(패키지 및 환경변수)
# - pip install openai langchain-openai

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 2. LLM 답변 생성
# ### 2.1 openAI SDK 를 선택
# - 세밀한 제어가 필요할 때, 성능 최적화가 중요할 때

# %%
from openai import OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4.1-nano",
    messages = [
        {"role":"system", "content":"너는 친절하게 대답해 주는 비서야"},
        {"role":"user",   "content":"2020년 월드 시리즈 누가 우승했어?"}
    ]
)

# %%
response.choices[0].message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승했습니다. 다저스는 탬파베이 레이스를 4승 2패로 이기고 챔피언이 되었어요.'

# %% [markdown]
# ### 2.2 LangChain을 선택
# - 내부적으로 자동 메세지 형태를 변환해 줌

# %%
from langchain_openai import ChatOpenAI
# .env OPEN_API_KEY가 등록
llm = ChatOpenAI(
    model = "gpt-4.1-nano" # 기본 모델 : gpt-3.5-turbo
)
ai_message = llm.invoke("2020년 월드 시리즈 누가 우승했나요?")

# %%
ai_message.content
# Out:
# '2020년 월드 시리즈는 로스앤젤레스 다저스가 우승을 차지했습니다. 다저스는 탬파베이 레이스를 4승 2패로 이기고 오랜만에 우승을 차지했으며, 이는 다저스의 7번째 월드 시리즈 우승입니다.'
